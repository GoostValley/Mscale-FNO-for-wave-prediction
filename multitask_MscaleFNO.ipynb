# %% [markdown]
# ## Mscale FNO for wave prediction
#
# This notebook implement the multi-task leanring for Mscale FNO 3d model.

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='2'
from neuralop.models import TFNO,FNO
import torch
import torch.nn.functional as F
import numpy as np
torch.manual_seed(0)
np.random.seed(0)
import logging
import datetime
import glob
from utilities3 import *

# %%
def read_data(file_paths, inlen=16, outlen=16):
    eta = []
    scatter = []
    len = inlen + outlen
    for f in file_paths:
        reader = MatReader(f, to_torch=False)
        eta_tmp = reader.read_field('eta')
        scatter_tmp = reader.read_field('scatter')
        eta_tmp = eta_tmp[:,:,:,117:437]
        scatter_tmp = scatter_tmp[:,:,:,117:437]
        #print(eta_tmp.shape,scatter_tmp.shape)
        slice_eta = []
        slice_scatter = []
        for i in range(10):
            slice_eta.append(eta_tmp[:,:,:,32*i:32*(i+1)])
            slice_scatter.append(scatter_tmp[:,:,:,32*i:32*(i+1)])
        eta_tmp = np.concatenate(slice_eta,axis=0)
        scatter_tmp = np.concatenate(slice_scatter,axis=0)
        #print(eta_tmp.shape,scatter_tmp.shape)
        x = reader.read_field('x').flatten()
        y = reader.read_field('y').flatten()
        t = reader.read_field('t').flatten()
        t = t[0:32] 
        if eta == []:
            eta = eta_tmp
            scatter = scatter_tmp
        else:
            eta = np.concatenate([eta,eta_tmp])
            scatter = np.concatenate([scatter,scatter_tmp])
    return eta, scatter, x, y, t

def split_data(eta, scatter, train_test_split=[0.6,0.2,0.2], inlen=16, outlen=16, sub=2, to_torch=False):
    train_size = int(eta.shape[0]*train_test_split[0])
    test_size = int(eta.shape[0]*train_test_split[2])
    train_a = scatter[:train_size,::sub,::sub,:inlen]
    train_e = eta[:train_size,::sub,::sub,:inlen]
    train_u = eta[:train_size,::sub,::sub,inlen:inlen+outlen]
    val_a = scatter[train_size:train_size+test_size,::sub,::sub,:inlen]
    val_e = eta[train_size:train_size+test_size,::sub,::sub,:inlen]
    val_u = eta[train_size:train_size+test_size,::sub,::sub,inlen:inlen+outlen]
    test_a = scatter[train_size+test_size:,::sub,::sub,:inlen]
    test_e = eta[train_size+test_size:,::sub,::sub,:inlen]
    test_u = eta[train_size+test_size:,::sub,::sub,inlen:inlen+outlen]
    if to_torch:
        train_a = torch.from_numpy(train_a)
        train_e = torch.from_numpy(train_e)
        train_u = torch.from_numpy(train_u)
        val_a = torch.from_numpy(val_a)
        val_e = torch.from_numpy(val_e)
        val_u = torch.from_numpy(val_u)
        test_a = torch.from_numpy(test_a)
        test_e = torch.from_numpy(test_e)
        test_u = torch.from_numpy(test_u)
    return train_a, train_e, train_u, val_a, val_e, val_u, test_a, test_e, test_u

# read and split data, for each datafile, spilit it in to train,val and test then concatenate them, add hs and spread tag in the filename, length the same as the test array
def read_and_split(file_paths, train_test_split=[0.6,0.2,0.2], inlen=16, outlen=16, sub=2, to_torch=False):
    eta, scatter, x, y, t = read_data([file_paths[0]], inlen=inlen, outlen=outlen)
    train_a, train_e, train_u, val_a, val_e, val_u, test_a, test_e, test_u = split_data(eta, scatter, train_test_split=train_test_split, inlen=inlen, outlen=outlen, sub=sub, to_torch=to_torch)
    hs = float(file_paths[0].split('angle')[1].split('h')[1].split('.mat')[0]) * np.ones(test_a.shape[0])   
    spread = float(file_paths[0].split('angle')[1].split('h')[0]) * np.ones(test_a.shape[0]) 

    for i,f in enumerate(file_paths):
        if i>0:
            eta, scatter, x, y, t = read_data([f], inlen=inlen, outlen=outlen)
            train_a_tmp, train_e_tmp, train_u_tmp, val_a_tmp, val_e_tmp, val_u_tmp, test_a_tmp, test_e_tmp, test_u_tmp = split_data(eta, scatter, train_test_split=train_test_split, inlen=inlen, outlen=outlen, sub=sub, to_torch=to_torch)
            train_a = np.concatenate([train_a,train_a_tmp])
            train_e = np.concatenate([train_e,train_e_tmp])
            train_u = np.concatenate([train_u,train_u_tmp])
            val_a = np.concatenate([val_a,val_a_tmp])
            val_e = np.concatenate([val_e,val_e_tmp])
            val_u = np.concatenate([val_u,val_u_tmp])
            test_a = np.concatenate([test_a,test_a_tmp])
            test_e = np.concatenate([test_e,test_e_tmp])
            test_u = np.concatenate([test_u,test_u_tmp])
            hs = np.concatenate([hs,float(f.split('angle')[1].split('h')[1].split('.mat')[0]) * np.ones(test_a_tmp.shape[0])])
            spread = np.concatenate([spread,float(f.split('angle')[1].split('h')[0]) * np.ones(test_a_tmp.shape[0])])
    if to_torch:
        train_a = torch.from_numpy(train_a)
        train_e = torch.from_numpy(train_e)
        train_u = torch.from_numpy(train_u)
        val_a = torch.from_numpy(val_a)
        val_e = torch.from_numpy(val_e)
        val_u = torch.from_numpy(val_u)
        test_a = torch.from_numpy(test_a)
        test_e = torch.from_numpy(test_e)
        test_u = torch.from_numpy(test_u)
        hs = torch.from_numpy(hs)
        spread = torch.from_numpy(spread)

    return train_a, train_e, train_u, val_a, val_e, val_u, test_a, test_e, test_u, x, y, t, hs, spread

dirs = os.listdir("./mixed_data")
dirs = [os.path.join("./mixed_data",d) for d in dirs]
# add another dir
dirs2 = os.listdir("./mixed_data2")
dirs2 = [os.path.join("./mixed_data2",d) for d in dirs2]
dirs = dirs + dirs2
train_a, train_e, train_u, val_a, val_e, val_u, test_a, test_e, test_u,x_domain,y_domain,t_domain,hs, spread = read_and_split(dirs,inlen=16,outlen=16,sub=2,to_torch=True)

# %% [markdown]
# **Change your config here**

# %%
# parameter and logging setup
modesxy = 32 # modes in x,y dimension
modest = 8 # modes in t dimension
width = 32 # width in FNO layer
n_net = 8 # number of sub-network
multiscale = True # is multi-scale
cnnfusion = True # is using conv-block
learning_rate = 0.001 
epochs = 500
batch_size = 20
iterations = epochs*(train_u.shape[0]//batch_size)
prefix = "conv_kernel3_layer3" # experiment name prefix
path = 'exp/'+prefix+ '_m' + str(modesxy) + str(modest) + '_w' + str(width)+ 'multi'+str(multiscale) + '_n' + str(n_net) + '_c' + str(cnnfusion) 
if not os.path.exists(path):
    os.mkdir(path)
path_model = path+'/model'
path_train_err = path+'/train.txt'
path_test_err = path+'/test.txt'
path_image = path+'/image'
if not os.path.exists(path_image):
    os.mkdir(path_image)
logger = logging.getLogger("logger")
logger.setLevel(logging.INFO)
sh = logging.StreamHandler()
log_file = path+'/train'+ datetime.datetime.now().strftime('%Y%m%d_%H%M%S')+'.log'
fh = logging.FileHandler(log_file,encoding="UTF-8")
formator = logging.Formatter(fmt = '%(asctime)s : %(message)s')
sh.setFormatter(formator)
fh.setFormatter(formator)
logger.addHandler(sh)
logger.addHandler(fh)

# %%
sub = 2  
S = 128 // sub
T_in = 16
T = 16 

ntrain = train_a.shape[0]
nval = val_a.shape[0]
ntest = test_a.shape[0]
train_a = train_a.reshape(ntrain,S,S,1,T_in).repeat([1,1,1,T,1])
val_a = val_a.reshape(nval,S,S,1,T_in).repeat([1,1,1,T,1])
test_a = test_a.reshape(ntest,S,S,1,T_in).repeat([1,1,1,T,1])

# %%
# not used here, if you are interested, you can add compact activation to your experiment
class CompactActivation(nn.Module):
    def __init__(self):
        super(CompactActivation, self).__init__()
        self.relu = nn.ReLU()

    def forward(self, x):
        # (relu(x))^2 - 3(relu(x-1))^2 + 3(relu(x-2))^2 - (relu(x-3))^2
        return (self.relu(x))**2 - \
               3*(self.relu(x-1))**2 + \
               3*(self.relu(x-2))**2 - \
               (self.relu(x-3))**2


# vallina multi-scale FNO which is a combination of N FNO, parallel forward seems not work
class multiscaleFNO(nn.Module):
    def __init__(self,modes1,modes2,modes3,width,n_net):
        super(multiscaleFNO, self).__init__()
        self.modes1 = modes1
        self.modes2 = modes2
        self.modes3 = modes3
        self.width = width
        self.n_net = n_net
        self.fno_subnets = nn.ModuleList([FNO(n_modes=(self.modes1,self.modes2,self.modes3),
                          n_layers=4,hidden_channels=self.width, 
                          lifting_channels = 2*self.width, 
                          projection_channels=2*self.width,in_channels=T_in+3, out_channels=1) for _ in range(n_net)])
        #self.cs = nn.Parameter(torch.randn(n_net), requires_grad=True)
        # give initial value to cs
        self.cs = torch.nn.Parameter(torch.pow(2,torch.arange(-1,n_net-1,dtype=torch.float32)),requires_grad=True) 
        #cs as predefined tensor,gamma are equal weight 1/n_net
        self.gammas = torch.nn.Parameter(torch.tensor([1.0/n_net]*n_net),requires_grad=True)

    def forward(self,x):
        results = []
        for i in range(self.n_net):
            scaled_x = self.cs[i] * x
            subnet_output = self.fno_subnets[i](scaled_x)
            weighted_output = self.gammas[i] * subnet_output
            results.append(weighted_output)
        u = sum(results)
        return u
    
    def forward2(self,x):
        scaled_x = self.cs.view(self.n_net, 1, 1, 1, 1, 1) * x.unsqueeze(0)  # [n_net, batch, channel, x, y, t]
        subnet_outputs = torch.stack([
            self.fno_subnets[i](scaled_x[i]) for i in range(self.n_net)
        ], dim=0)  # [n_net, batch, out_channels, x, y, t]

        weighted_outputs = self.gammas.view(self.n_net, 1, 1, 1, 1, 1) * subnet_outputs
        return weighted_outputs.sum(dim=0)  

    def forward3(self,x):
        futures = []
        for i in range(self.n_net):
            scaled_x = self.cs[i] * x
            fut = torch.jit.fork(self.fno_subnets[i], scaled_x)
            futures.append((fut, i))
    
        results = []
        for fut, i in futures:
            subnet_output = torch.jit.wait(fut)  
            weighted_output = self.gammas[i] * subnet_output
            results.append(weighted_output)

        u = sum(results)
        return u

    # jit
    def forward4(self, x):
        # jit.fork
        futures = [torch.jit.fork(subnet, x * c) 
                for subnet, c in zip(self.fno_subnets, self.cs)]

        outputs = [torch.jit.wait(fut) for fut in futures]

        return sum(g * out for g, out in zip(self.gammas, outputs))

# testcase, input shape [batch, chanel, S, S, T_in]
#input = torch.randn(10, 19, 32, 32, 16)
#model = multiscaleFNO(8, 8, 8, 32, n_net=4)
#output = model(input)
#output = model.forward4(input)
#print("input shape: ", input.shape)
#print("output shape: ", output.shape)

# %%
class Sin(nn.Module):
    def __init__(self):
        super(Sin, self).__init__()
        
    def forward(self, x):
        return torch.sin(x)

class res_conv_block(nn.Module):
    def __init__(self,n_net):
        super(res_conv_block,self).__init__()
        self.conv0 = nn.Conv3d(in_channels=n_net,out_channels=64,kernel_size=1,padding=0)
        self.blocks = nn.ModuleList([
            nn.Sequential(
                nn.Conv3d(64, 64, kernel_size=3, padding=1),
                nn.BatchNorm3d(64)
                ) for _ in range (3)
        ])
        self.conv1 = nn.Conv3d(in_channels=64,out_channels=1,kernel_size=1,padding=0)
    def forward(self,x):
        x = self.conv0(x)
        for block in self.blocks:
            residual =x
            x = block(x)
            x += residual
            x = nn.ReLU(inplace=True)(x)
        x = self.conv1(x)
        #x  = nn.ReLU(inplace=True)(x)
        return x

class multiscaleFNOcnnFusion(nn.Module):
    def __init__(self, modes1, modes2, modes3, width, n_net):
        super(multiscaleFNOcnnFusion, self).__init__()
        self.modes1 = modes1
        self.modes2 = modes2
        self.modes3 = modes3
        self.width = width
        self.n_net = n_net
        
        self.fno_subnets = nn.ModuleList([
            FNO(n_modes=(self.modes1, self.modes2, self.modes3),
                n_layers=4,
                hidden_channels=self.width, 
                lifting_channels=2*self.width,
                projection_channels=2*self.width,
                in_channels=T_in+3,
                out_channels=1
                ) 
            for _ in range(n_net)
        ])
        
        self.cs = torch.nn.Parameter(
            torch.pow(2, torch.arange(-2, n_net-2, dtype=torch.float32)),
            requires_grad=True
        )
        #self.fusion_net = res_conv_block(n_net)
        # 3layer 
        self.fusion_net = nn.Sequential(
            nn.Conv3d(n_net, 32, kernel_size=5, padding=2),
            nn.BatchNorm3d(32),
            nn.ReLU(),
 
            nn.Conv3d(32, 64, kernel_size=5, padding=2),
            nn.BatchNorm3d(64),
            nn.ReLU(),

            nn.Conv3d(64, 32, kernel_size=5, padding=2),
            nn.BatchNorm3d(32),
            nn.ReLU(),

            nn.Conv3d(32, 1, kernel_size=1),
        )

    def forward(self, x):
        subnet_outputs = []
        for i in range(self.n_net):
            scaled_x = self.cs[i] * x
            subnet_output = self.fno_subnets[i](scaled_x)
            subnet_outputs.append(subnet_output)
        
        #  [batch, n_net, x, y, t]
        stacked_outputs = torch.stack(subnet_outputs, dim=1).squeeze(2)
        # stacked_outputs.shape = [batch, n_net, x, y, t]
        #print("stacked_outputs shape: ", stacked_outputs.shape)
        fused_output = self.fusion_net(stacked_outputs)
        
        return fused_output

# testcase, input shape [batch, chanel, S, S, T_in]
#input = torch.randn(10, 19, 64, 64, 16)
#model = multiscaleFNOcnnFusion(8, 8, 8, 32, n_net=8)
#output = model(input)
#print("input shape: ", input.shape)
#print("output shape: ", output.shape)

# %%
class FNO_multi(nn.Module):
    def __init__(self, modes1, modes2, modes3, width, n_net=8, multiscale=False,cnnfusion=False):
        super(FNO_multi, self).__init__()
        self.modes1 = modes1
        self.modes2 = modes2
        self.modes3 = modes3
        self.width = width
        '''
        self.fno_r = TFNO(n_modes=(self.modes1, self.modes2, self.modes3), hidden_channels=self.width,
                        in_channels=19,
                        out_channels=1,
                        factorization='tucker',
                        implementation='factorized',
                        n_layers=4,
                        rank=0.05)
        self.fno_p = TFNO(n_modes=(self.modes1, self.modes2, self.modes3), hidden_channels=self.width,
                        in_channels=19,
                        out_channels=1,
                        factorization='tucker',
                        implementation='factorized',
                        n_layers=4,
                        rank=0.05)
        '''
        if multiscale:
            if cnnfusion:
                self.fno_r = multiscaleFNOcnnFusion(self.modes1, self.modes2, self.modes3, self.width, n_net=n_net)
                self.fno_p = multiscaleFNOcnnFusion(self.modes1, self.modes2, self.modes3, self.width, n_net=n_net)
            else:
                self.fno_r = multiscaleFNO(self.modes1, self.modes2, self.modes3, self.width, n_net=n_net)
                self.fno_p = multiscaleFNO(self.modes1, self.modes2, self.modes3, self.width, n_net=n_net)
        else:
            self.fno_r = FNO(n_modes=(self.modes1,self.modes2,self.modes3), n_layers=4,hidden_channels=self.width, lifting_channels = 2*self.width, projection_channels=2*self.width,in_channels=19, out_channels=1)
            self.fno_p = FNO(n_modes=(self.modes1,self.modes2,self.modes3), n_layers=4,hidden_channels=self.width, lifting_channels = 2*self.width, projection_channels=2*self.width,in_channels=19, out_channels=1)
    
    def forward(self,x):
        x = self.get_grid(x)
        x = self.fno_r(x)
        y = x.permute(0,2,3,1,4).repeat([1,1,1,16,1])
        y = self.get_grid(y)
        y = self.fno_p(y)
        return x,y     
    def get_grid(self,x):
        # x[batch,x,y,t,c]
        # output[batch,c+3,x,y,t]
        shape,device = x.shape,x.device
        batchsize, size_x, size_y, size_z = shape[0], shape[1], shape[2], shape[3]
        gridx = torch.tensor(np.linspace(0, x_domain[-1]-x_domain[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1, 1).repeat([batchsize, 1, size_y, size_z, 1])
        gridy = torch.tensor(np.linspace(0, y_domain[-1]-y_domain[0], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1, 1).repeat([batchsize, size_x, 1, size_z, 1])
        gridz = torch.tensor(np.linspace(0, t_domain[-1]-t_domain[0], size_z), dtype=torch.float)
        gridz = gridz.reshape(1, 1, 1, size_z, 1).repeat([batchsize, size_x, size_y, 1, 1])
        grid = torch.cat((gridx, gridy, gridz), dim=-1).to(device)
        x = torch.cat((x,grid),dim=-1)
        x = x.permute(0,4,1,2,3)
        return x

# %%
def ssp_loss(pred, true, ax=(1, 2)):
    fpred = torch.fft.fftn(pred, dim=ax)
    ftrue = torch.fft.fftn(true, dim=ax)
    norm_error = torch.norm(fpred-ftrue, dim=ax)
    norm_pred = torch.norm(fpred, dim=ax)
    norm_true = torch.norm(ftrue, dim=ax)
    ssps = norm_error / (norm_pred + norm_true)
    ssp = torch.sum(torch.mean(ssps, dim=-1))
    return ssp

device = torch.device('cuda')
model = FNO_multi(modesxy,modesxy,modest,width,n_net,multiscale,cnnfusion).cuda() 
#print(count_params(model))
logger.info("models params: %d" % count_params(model))
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=iterations)
myloss = LpLoss(size_average=False)
#myloss = F.mse_loss(reduction='mean')
train_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(train_a, train_u,train_e), batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(val_a, val_u,val_e), batch_size=batch_size, shuffle=False)
# Out:
# 2025-10-18 04:38:51,585 : models params: 134915490

# %%
from timeit import default_timer
gamma = 1.0
best_err = 1e10
for ep in range(epochs):
    model.train()
    t1 = default_timer()
    train_mse_e = 0
    train_mse_u = 0
    train_l2_e = 0 
    train_l2_u = 0
    train_ssp_e = 0
    train_ssp_u = 0
    for x, y ,e in train_loader:
        x, y ,e = x.cuda(), y.cuda(), e.cuda()
        optimizer.zero_grad()
        outeta,out = model(x)
        out = out.view(batch_size, S, S, T)
        outeta = outeta.view(batch_size,S,S,T)

        mse_u = F.mse_loss(out, y, reduction='mean')
        mse_e = F.mse_loss(outeta, e, reduction='mean')

        l2_u = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2_e = myloss(outeta.view(batch_size, -1),e.view(batch_size, -1))
        ssp_e = ssp_loss(outeta,e)
        ssp_u = ssp_loss(out,y)
        l2 = l2_u+gamma* l2_e#+ssp_e+gamma*ssp_u
        #l2 = mse_u + gamma*mse_e
        l2.backward()

        optimizer.step()
        scheduler.step()
        train_mse_e += mse_e.item()
        train_mse_u += mse_u.item()
        train_l2_e += l2_e.item()
        train_l2_u += l2_u.item()
        train_ssp_e += ssp_e.item()
        train_ssp_u += ssp_u.item()

    model.eval()
    test_l2 = 0.0
    test_l2_e = 0.0
    test_l2_u = 0.0
    with torch.no_grad():
        for x, y, e in val_loader:
            x, y ,e = x.cuda(), y.cuda(), e.cuda()

            outeta,out = model(x)
            out = out.view(batch_size, S, S, T)
            outeta = outeta.view(batch_size,S,S,T)
#            out = y_normalizer.decode(out)
            test_l2_u += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
            test_l2_e += myloss(outeta.view(batch_size, -1),e.view(batch_size, -1)).item()

    train_mse_e /= len(train_loader)
    train_mse_u /= len(train_loader)
    train_l2_e /= ntrain
    train_l2_u /= ntrain
    train_ssp_e /= ntrain
    train_ssp_u /= ntrain
    test_l2_e /= ntest
    test_l2_u /= ntest

    t2 = default_timer()
    #print(ep, t2-t1, train_mse_e,train_mse_u, train_l2_e,train_l2_u,test_l2_e, test_l2_u)
    logger.info('epoch:%d, time:%f, train_mse_e:%f, train_mse_u:%f, train_l2_e:%f, train_l2_u:%f, train_ssp_e:%f, train_ssp_u:%f,test_l2_e:%f, test_l2_u:%f'%
               (ep, t2-t1, train_mse_e,train_mse_u, train_l2_e,train_l2_u,train_ssp_e,train_ssp_u,test_l2_e, test_l2_u))
    if test_l2_u<best_err:
        best_err = test_l2_u
        torch.save(model, path_model)
        logger.info('best model saved')
# Out:
# 2025-10-18 04:39:27,250 : epoch:0, time:35.643630, train_mse_e:1.963805, train_mse_u:0.814142, train_l2_e:2.046303, train_l2_u:1.266463, train_ssp_e:0.792451, train_ssp_u:0.841687,test_l2_e:1.048204, test_l2_u:1.015782
# 2025-10-18 04:39:28,050 : best model saved
# 2025-10-18 04:40:01,723 : epoch:1, time:33.666396, train_mse_e:0.466719, train_mse_u:0.610112, train_l2_e:0.840851, train_l2_u:1.020655, train_ssp_e:0.623787, train_ssp_u:0.903694,test_l2_e:0.636064, test_l2_u:1.001139
# 2025-10-18 04:40:02,377 : best model saved
# 2025-10-18 04:40:36,563 : epoch:2, time:34.182002, train_mse_e:0.183929, train_mse_u:0.607055, train_l2_e:0.531026, train_l2_u:1.005810, train_ssp_e:0.291867, train_ssp_u:0.942897,test_l2_e:0.493439, test_l2_u:1.001190
# 2025-10-18 04:41:09,954 : epoch:3, time:33.386558, train_mse_e:0.098052, train_mse_u:0.603849, train_l2_e:0.397610, train_l2_u:0.998841, train_ssp_e:0.206889, train_ssp_u:0.957697,test_l2_e:0.357780, test_l2_u:0.992328
# 2025-10-18 04:41:10,616 : best model saved
# 2025-10-18 04:41:43,711 : epoch:4, time:33.091747, train_mse_e:0.074475, train_mse_u:0.539047, train_l2_e:0.356807, train_l2_u:0.942426, train_ssp_e:0.182136, train_ssp_u:0.764851,test_l2_e:0.446503, test_l2_u:0.877859
# 2025-10-18 04:41:44,364 : best model saved
# 2025-10-18 04:42:17,511 : epoch:5, time:33.144183, train_mse_e:0.067940, train_mse_u:0.409196, train_l2_e:0.351147, train_l2_u:0.822622, train_ssp_e:0.177554, train_ssp_u:0.543754,test_l2_e:0.368342, test_l2_u:0.761472
# 2025-10-18 04:42:18,169 : best model saved
# 2025-10-18 04:42:51,203 : epoch:6, time:33.030618, train_mse_e:0.061538, train_mse_u:0.289577, train_l2_e:0.328801, train_l2_u:0.696727, train_ssp_e:0.166373, train_ssp_u:0.415848,test_l2_e:0.355455, test_l2_u:0.645094
# 2025-10-18 04:42:51,856 : best model saved
# 2025-10-18 04:43:24,761 : epoch:7, time:32.902305, train_mse_e:0.055899, train_mse_u:0.206119, train_l2_e:0.309473, train_l2_u:0.603649, train_ssp_e:0.157075, train_ssp_u:0.334515,test_l2_e:0.344911, test_l2_u:0.660237
# 2025-10-18 04:43:57,716 : epoch:8, time:32.947638, train_mse_e:0.053298, train_mse_u:0.173570, train_l2_e:0.303507, train_l2_u:0.563620, train_ssp_e:0.153231, train_ssp_u:0.304259,test_l2_e:0.285613, test_l2_u:0.521409
# 2025-10-18 04:43:58,518 : best model saved
# 2025-10-18 04:44:32,165 : epoch:9, time:33.643310, train_mse_e:0.047370, train_mse_u:0.145547, train_l2_e:0.282749, train_l2_u:0.496005, train_ssp_e:0.142908, train_ssp_u:0.265989,test_l2_e:0.288313, test_l2_u:0.485191
# 2025-10-18 04:44:32,965 : best model saved
# 2025-10-18 04:45:06,034 : epoch:10, time:33.066102, train_mse_e:0.045612, train_mse_u:0.131261, train_l2_e:0.283834, train_l2_u:0.469470, train_ssp_e:0.142920, train_ssp_u:0.250023,test_l2_e:0.317778, test_l2_u:0.463658
# 2025-10-18 04:45:06,848 : best model saved
# 2025-10-18 04:45:39,937 : epoch:11, time:33.085574, train_mse_e:0.043753, train_mse_u:0.121716, train_l2_e:0.278573, train_l2_u:0.451445, train_ssp_e:0.140027, train_ssp_u:0.238947,test_l2_e:0.274080, test_l2_u:0.467027
# 2025-10-18 04:46:13,008 : epoch:12, time:33.066563, train_mse_e:0.039605, train_mse_u:0.115255, train_l2_e:0.249948, train_l2_u:0.449791, train_ssp_e:0.126288, train_ssp_u:0.235666,test_l2_e:0.256698, test_l2_u:0.483050
# 2025-10-18 04:46:45,962 : epoch:13, time:32.949509, train_mse_e:0.037851, train_mse_u:0.109000, train_l2_e:0.248310, train_l2_u:0.434881, train_ssp_e:0.125318, train_ssp_u:0.227596,test_l2_e:0.257110, test_l2_u:0.464793
# 2025-10-18 04:47:18,836 : epoch:14, time:32.869114, train_mse_e:0.035663, train_mse_u:0.100459, train_l2_e:0.238365, train_l2_u:0.413281, train_ssp_e:0.120282, train_ssp_u:0.215281,test_l2_e:0.252057, test_l2_u:0.455275
# 2025-10-18 04:47:19,543 : best model saved
# 2025-10-18 04:47:52,461 : epoch:15, time:32.915230, train_mse_e:0.035484, train_mse_u:0.097139, train_l2_e:0.246263, train_l2_u:0.411593, train_ssp_e:0.123549, train_ssp_u:0.214510,test_l2_e:0.276893, test_l2_u:0.437641
# 2025-10-18 04:47:53,123 : best model saved
# 2025-10-18 04:48:26,079 : epoch:16, time:32.952263, train_mse_e:0.032450, train_mse_u:0.090209, train_l2_e:0.229436, train_l2_u:0.391524, train_ssp_e:0.115016, train_ssp_u:0.202823,test_l2_e:0.240315, test_l2_u:0.424558
# 2025-10-18 04:48:26,736 : best model saved
# 2025-10-18 04:48:59,662 : epoch:17, time:32.922723, train_mse_e:0.033647, train_mse_u:0.090926, train_l2_e:0.235270, train_l2_u:0.397812, train_ssp_e:0.118592, train_ssp_u:0.206816,test_l2_e:0.243281, test_l2_u:0.420676
# 2025-10-18 04:49:00,321 : best model saved
# 2025-10-18 04:49:33,224 : epoch:18, time:32.899508, train_mse_e:0.032009, train_mse_u:0.086113, train_l2_e:0.233039, train_l2_u:0.388099, train_ssp_e:0.116881, train_ssp_u:0.200754,test_l2_e:0.247021, test_l2_u:0.435060
# 2025-10-18 04:50:06,110 : epoch:19, time:32.883465, train_mse_e:0.033526, train_mse_u:0.089308, train_l2_e:0.241349, train_l2_u:0.407174, train_ssp_e:0.120632, train_ssp_u:0.209744,test_l2_e:0.265989, test_l2_u:0.440383
# 2025-10-18 04:50:38,912 : epoch:20, time:32.797626, train_mse_e:0.031457, train_mse_u:0.085566, train_l2_e:0.231816, train_l2_u:0.387805, train_ssp_e:0.116518, train_ssp_u:0.200385,test_l2_e:0.275903, test_l2_u:0.427553
# 2025-10-18 05:22:42,692 : epoch:78, time:32.978064, train_mse_e:0.016095, train_mse_u:0.041470, train_l2_e:0.158387, train_l2_u:0.275235, train_ssp_e:0.079272, train_ssp_u:0.139742,test_l2_e:0.195092, test_l2_u:0.376517
# 2025-10-18 05:22:43,434 : best model saved
# 2025-10-18 05:23:16,511 : epoch:79, time:33.070226, train_mse_e:0.017512, train_mse_u:0.044859, train_l2_e:0.167794, train_l2_u:0.282558, train_ssp_e:0.084081, train_ssp_u:0.144445,test_l2_e:0.225920, test_l2_u:0.432578
# 2025-10-18 05:23:49,662 : epoch:80, time:33.145935, train_mse_e:0.018440, train_mse_u:0.047193, train_l2_e:0.173262, train_l2_u:0.290878, train_ssp_e:0.086520, train_ssp_u:0.148678,test_l2_e:0.200841, test_l2_u:0.391316
# 2025-10-18 05:24:22,829 : epoch:81, time:33.161351, train_mse_e:0.016213, train_mse_u:0.042181, train_l2_e:0.157163, train_l2_u:0.275739, train_ssp_e:0.078795, train_ssp_u:0.140320,test_l2_e:0.198291, test_l2_u:0.386041
# 2025-10-18 05:24:55,954 : epoch:82, time:33.119970, train_mse_e:0.016202, train_mse_u:0.041080, train_l2_e:0.161104, train_l2_u:0.271340, train_ssp_e:0.080757, train_ssp_u:0.137957,test_l2_e:0.193317, test_l2_u:0.389010
# 2025-10-18 05:25:29,062 : epoch:83, time:33.100494, train_mse_e:0.015392, train_mse_u:0.039126, train_l2_e:0.155063, train_l2_u:0.261927, train_ssp_e:0.077733, train_ssp_u:0.133143,test_l2_e:0.192697, test_l2_u:0.373338
# 2025-10-18 05:25:29,860 : best model saved
# 2025-10-18 05:26:02,953 : epoch:84, time:33.088596, train_mse_e:0.015555, train_mse_u:0.040774, train_l2_e:0.153302, train_l2_u:0.269795, train_ssp_e:0.076882, train_ssp_u:0.136651,test_l2_e:0.191871, test_l2_u:0.377417
# 2025-10-18 05:26:35,949 : epoch:85, time:32.990845, train_mse_e:0.015076, train_mse_u:0.039534, train_l2_e:0.152523, train_l2_u:0.264503, train_ssp_e:0.076464, train_ssp_u:0.134353,test_l2_e:0.191846, test_l2_u:0.378991
# 2025-10-18 05:27:09,006 : epoch:86, time:33.052502, train_mse_e:0.015059, train_mse_u:0.039218, train_l2_e:0.151527, train_l2_u:0.261039, train_ssp_e:0.075914, train_ssp_u:0.132657,test_l2_e:0.188850, test_l2_u:0.373172
# 2025-10-18 05:27:09,782 : best model saved
# 2025-10-18 05:27:42,737 : epoch:87, time:32.951993, train_mse_e:0.014744, train_mse_u:0.038705, train_l2_e:0.148747, train_l2_u:0.259264, train_ssp_e:0.074558, train_ssp_u:0.131771,test_l2_e:0.190995, test_l2_u:0.373456
# 2025-10-18 05:28:15,671 : epoch:88, time:32.927492, train_mse_e:0.014725, train_mse_u:0.038505, train_l2_e:0.148241, train_l2_u:0.257562, train_ssp_e:0.074357, train_ssp_u:0.130914,test_l2_e:0.187206, test_l2_u:0.381176
# 2025-10-18 05:28:48,533 : epoch:89, time:32.856729, train_mse_e:0.014497, train_mse_u:0.037942, train_l2_e:0.148166, train_l2_u:0.258694, train_ssp_e:0.074144, train_ssp_u:0.131427,test_l2_e:0.193886, test_l2_u:0.384030
# 2025-10-18 05:29:21,468 : epoch:90, time:32.930219, train_mse_e:0.016249, train_mse_u:0.042825, train_l2_e:0.157724, train_l2_u:0.278511, train_ssp_e:0.079015, train_ssp_u:0.142067,test_l2_e:0.214407, test_l2_u:0.402533
# 2025-10-18 05:29:54,531 : epoch:91, time:33.055562, train_mse_e:0.016078, train_mse_u:0.041393, train_l2_e:0.158775, train_l2_u:0.270773, train_ssp_e:0.079422, train_ssp_u:0.138065,test_l2_e:0.216545, test_l2_u:0.379504
# 2025-10-18 05:30:27,700 : epoch:92, time:33.163784, train_mse_e:0.014660, train_mse_u:0.037089, train_l2_e:0.151320, train_l2_u:0.253742, train_ssp_e:0.075808, train_ssp_u:0.128774,test_l2_e:0.192324, test_l2_u:0.375356
# 2025-10-18 05:31:00,762 : epoch:93, time:33.056064, train_mse_e:0.014574, train_mse_u:0.036601, train_l2_e:0.148121, train_l2_u:0.251197, train_ssp_e:0.074232, train_ssp_u:0.127358,test_l2_e:0.189531, test_l2_u:0.371116
# 2025-10-18 05:31:01,436 : best model saved
# 2025-10-18 05:31:34,438 : epoch:94, time:32.998777, train_mse_e:0.014620, train_mse_u:0.036506, train_l2_e:0.149460, train_l2_u:0.252876, train_ssp_e:0.074879, train_ssp_u:0.128269,test_l2_e:0.205577, test_l2_u:0.403092
# 2025-10-18 05:32:07,346 : epoch:95, time:32.902682, train_mse_e:0.015408, train_mse_u:0.038278, train_l2_e:0.156351, train_l2_u:0.260139, train_ssp_e:0.078255, train_ssp_u:0.131947,test_l2_e:0.187951, test_l2_u:0.373009
# 2025-10-18 05:32:40,108 : epoch:96, time:32.759085, train_mse_e:0.014541, train_mse_u:0.035205, train_l2_e:0.149292, train_l2_u:0.248123, train_ssp_e:0.074759, train_ssp_u:0.125519,test_l2_e:0.188776, test_l2_u:0.366074
# 2025-10-18 05:32:40,828 : best model saved
# 2025-10-18 05:33:13,768 : epoch:97, time:32.937045, train_mse_e:0.014711, train_mse_u:0.035528, train_l2_e:0.148585, train_l2_u:0.250096, train_ssp_e:0.074435, train_ssp_u:0.126538,test_l2_e:0.195420, test_l2_u:0.380521
# 2025-10-18 05:33:46,685 : epoch:98, time:32.910190, train_mse_e:0.014983, train_mse_u:0.035900, train_l2_e:0.150020, train_l2_u:0.249817, train_ssp_e:0.075171, train_ssp_u:0.126288,test_l2_e:0.186566, test_l2_u:0.396037
# 2025-10-18 05:34:19,613 : epoch:99, time:32.921307, train_mse_e:0.014455, train_mse_u:0.034318, train_l2_e:0.151159, train_l2_u:0.246794, train_ssp_e:0.075650, train_ssp_u:0.124456,test_l2_e:0.191205, test_l2_u:0.364195
# 2025-10-18 05:34:20,326 : best model saved
# 2025-10-18 05:34:53,230 : epoch:100, time:32.900168, train_mse_e:0.014425, train_mse_u:0.032560, train_l2_e:0.153259, train_l2_u:0.238688, train_ssp_e:0.076709, train_ssp_u:0.120488,test_l2_e:0.198301, test_l2_u:0.391650
# 2025-10-18 05:35:26,348 : epoch:101, time:33.112458, train_mse_e:0.014651, train_mse_u:0.032899, train_l2_e:0.155230, train_l2_u:0.245322, train_ssp_e:0.077406, train_ssp_u:0.123702,test_l2_e:0.194447, test_l2_u:0.361523
# 2025-10-18 05:35:27,014 : best model saved
# 2025-10-18 05:36:00,146 : epoch:102, time:33.128047, train_mse_e:0.016189, train_mse_u:0.037985, train_l2_e:0.160356, train_l2_u:0.265187, train_ssp_e:0.080300, train_ssp_u:0.134226,test_l2_e:0.204819, test_l2_u:0.434118
# 2025-10-18 05:36:33,248 : epoch:103, time:33.096286, train_mse_e:0.015025, train_mse_u:0.033683, train_l2_e:0.153036, train_l2_u:0.248349, train_ssp_e:0.076645, train_ssp_u:0.124983,test_l2_e:0.190080, test_l2_u:0.370009
# 2025-10-18 05:37:06,233 : epoch:104, time:32.980512, train_mse_e:0.014589, train_mse_u:0.030689, train_l2_e:0.153271, train_l2_u:0.234497, train_ssp_e:0.076639, train_ssp_u:0.117971,test_l2_e:0.191104, test_l2_u:0.360383
# 2025-10-18 05:37:06,906 : best model saved
# 2025-10-18 05:37:39,867 : epoch:105, time:32.958207, train_mse_e:0.014738, train_mse_u:0.030333, train_l2_e:0.155431, train_l2_u:0.230066, train_ssp_e:0.077666, train_ssp_u:0.115627,test_l2_e:0.193563, test_l2_u:0.366362
# 2025-10-18 05:38:12,758 : epoch:106, time:32.885951, train_mse_e:0.014186, train_mse_u:0.028851, train_l2_e:0.146564, train_l2_u:0.221902, train_ssp_e:0.073465, train_ssp_u:0.111661,test_l2_e:0.188256, test_l2_u:0.351737
# 2025-10-18 05:38:13,431 : best model saved
# 2025-10-18 05:38:46,423 : epoch:107, time:32.988883, train_mse_e:0.013888, train_mse_u:0.027339, train_l2_e:0.147588, train_l2_u:0.219935, train_ssp_e:0.073776, train_ssp_u:0.110183,test_l2_e:0.193753, test_l2_u:0.357523
# 2025-10-18 05:39:19,304 : epoch:108, time:32.878212, train_mse_e:0.015220, train_mse_u:0.030224, train_l2_e:0.156606, train_l2_u:0.229375, train_ssp_e:0.078389, train_ssp_u:0.115559,test_l2_e:0.194906, test_l2_u:0.380862
# 2025-10-18 05:39:52,152 : epoch:109, time:32.843088, train_mse_e:0.015052, train_mse_u:0.029875, train_l2_e:0.151717, train_l2_u:0.227767, train_ssp_e:0.075983, train_ssp_u:0.114571,test_l2_e:0.190297, test_l2_u:0.368275
# 2025-10-18 05:40:24,975 : epoch:110, time:32.820422, train_mse_e:0.014746, train_mse_u:0.028330, train_l2_e:0.148792, train_l2_u:0.219398, train_ssp_e:0.074610, train_ssp_u:0.110470,test_l2_e:0.189174, test_l2_u:0.352729
# 2025-10-18 05:40:57,770 : epoch:111, time:32.791786, train_mse_e:0.014017, train_mse_u:0.026406, train_l2_e:0.146722, train_l2_u:0.213483, train_ssp_e:0.073467, train_ssp_u:0.107187,test_l2_e:0.188042, test_l2_u:0.352163
# 2025-10-18 05:41:30,255 : epoch:112, time:32.479810, train_mse_e:0.014015, train_mse_u:0.026870, train_l2_e:0.146957, train_l2_u:0.218523, train_ssp_e:0.073533, train_ssp_u:0.109686,test_l2_e:0.187545, test_l2_u:0.350154
# 2025-10-18 05:41:31,019 : best model saved
# 2025-10-18 05:42:03,982 : epoch:113, time:32.958099, train_mse_e:0.014824, train_mse_u:0.028183, train_l2_e:0.153134, train_l2_u:0.224720, train_ssp_e:0.076577, train_ssp_u:0.112846,test_l2_e:0.198544, test_l2_u:0.391100
# 2025-10-18 05:42:36,770 : epoch:114, time:32.783756, train_mse_e:0.014006, train_mse_u:0.026528, train_l2_e:0.147515, train_l2_u:0.218131, train_ssp_e:0.073774, train_ssp_u:0.109639,test_l2_e:0.187100, test_l2_u:0.352321
# 2025-10-18 05:43:09,815 : epoch:115, time:33.042348, train_mse_e:0.013810, train_mse_u:0.025397, train_l2_e:0.147669, train_l2_u:0.212491, train_ssp_e:0.073875, train_ssp_u:0.106123,test_l2_e:0.185844, test_l2_u:0.376381
# 2025-10-18 05:43:42,772 : epoch:116, time:32.952868, train_mse_e:0.013503, train_mse_u:0.023831, train_l2_e:0.145728, train_l2_u:0.201626, train_ssp_e:0.072973, train_ssp_u:0.100954,test_l2_e:0.186785, test_l2_u:0.347178
# 2025-10-18 05:43:43,454 : best model saved
# 2025-10-18 05:44:16,559 : epoch:117, time:33.102137, train_mse_e:0.013626, train_mse_u:0.024196, train_l2_e:0.144689, train_l2_u:0.202706, train_ssp_e:0.072526, train_ssp_u:0.101573,test_l2_e:0.188786, test_l2_u:0.354762
# 2025-10-18 05:44:49,567 : epoch:118, time:33.003583, train_mse_e:0.013512, train_mse_u:0.023861, train_l2_e:0.142783, train_l2_u:0.201407, train_ssp_e:0.071553, train_ssp_u:0.100988,test_l2_e:0.186123, test_l2_u:0.348346
# 2025-10-18 05:45:22,525 : epoch:119, time:32.953311, train_mse_e:0.013170, train_mse_u:0.022975, train_l2_e:0.143470, train_l2_u:0.201602, train_ssp_e:0.071732, train_ssp_u:0.100832,test_l2_e:0.187918, test_l2_u:0.343025
# 2025-10-18 05:45:23,200 : best model saved
# 2025-10-18 05:45:55,991 : epoch:120, time:32.787005, train_mse_e:0.013298, train_mse_u:0.023116, train_l2_e:0.145853, train_l2_u:0.200244, train_ssp_e:0.073014, train_ssp_u:0.100313,test_l2_e:0.186212, test_l2_u:0.362168
# 2025-10-18 05:46:28,724 : epoch:121, time:32.727523, train_mse_e:0.013707, train_mse_u:0.022767, train_l2_e:0.154336, train_l2_u:0.200666, train_ssp_e:0.076717, train_ssp_u:0.100129,test_l2_e:0.205040, test_l2_u:0.375790
# 2025-10-18 05:47:01,598 : epoch:122, time:32.868344, train_mse_e:0.013827, train_mse_u:0.023629, train_l2_e:0.152010, train_l2_u:0.204636, train_ssp_e:0.075761, train_ssp_u:0.102398,test_l2_e:0.186288, test_l2_u:0.343036
# 2025-10-18 05:47:34,530 : epoch:123, time:32.926813, train_mse_e:0.013175, train_mse_u:0.022338, train_l2_e:0.142986, train_l2_u:0.194709, train_ssp_e:0.071541, train_ssp_u:0.097410,test_l2_e:0.190982, test_l2_u:0.353202
# 2025-10-18 05:48:07,524 : epoch:124, time:32.988990, train_mse_e:0.013373, train_mse_u:0.022803, train_l2_e:0.144867, train_l2_u:0.198717, train_ssp_e:0.072499, train_ssp_u:0.099760,test_l2_e:0.189568, test_l2_u:0.350093
# 2025-10-18 05:48:40,445 : epoch:125, time:32.915586, train_mse_e:0.013207, train_mse_u:0.022192, train_l2_e:0.144833, train_l2_u:0.195369, train_ssp_e:0.072536, train_ssp_u:0.097948,test_l2_e:0.185772, test_l2_u:0.357004
# 2025-10-18 05:49:13,370 : epoch:126, time:32.920119, train_mse_e:0.012984, train_mse_u:0.021727, train_l2_e:0.140382, train_l2_u:0.191184, train_ssp_e:0.070306, train_ssp_u:0.095680,test_l2_e:0.184458, test_l2_u:0.341018
# 2025-10-18 05:49:14,153 : best model saved
# 2025-10-18 05:49:47,204 : epoch:127, time:33.048088, train_mse_e:0.012791, train_mse_u:0.021459, train_l2_e:0.138609, train_l2_u:0.191762, train_ssp_e:0.069391, train_ssp_u:0.096034,test_l2_e:0.183200, test_l2_u:0.346655
# 2025-10-18 05:50:20,275 : epoch:128, time:33.065369, train_mse_e:0.012765, train_mse_u:0.021215, train_l2_e:0.138512, train_l2_u:0.191025, train_ssp_e:0.069403, train_ssp_u:0.095626,test_l2_e:0.185281, test_l2_u:0.341193
# 2025-10-18 05:50:53,274 : epoch:129, time:32.994154, train_mse_e:0.012638, train_mse_u:0.020673, train_l2_e:0.139783, train_l2_u:0.188530, train_ssp_e:0.069897, train_ssp_u:0.094244,test_l2_e:0.185776, test_l2_u:0.339817
# 2025-10-18 05:50:54,007 : best model saved
# 2025-10-18 05:51:27,585 : epoch:130, time:33.573805, train_mse_e:0.013034, train_mse_u:0.021181, train_l2_e:0.146756, train_l2_u:0.191569, train_ssp_e:0.073428, train_ssp_u:0.095947,test_l2_e:0.189204, test_l2_u:0.342779
# 2025-10-18 05:52:01,134 : epoch:131, time:33.543802, train_mse_e:0.012868, train_mse_u:0.020876, train_l2_e:0.143501, train_l2_u:0.189121, train_ssp_e:0.071844, train_ssp_u:0.094613,test_l2_e:0.204022, test_l2_u:0.355257
# 2025-10-18 05:52:34,746 : epoch:132, time:33.607516, train_mse_e:0.012872, train_mse_u:0.020831, train_l2_e:0.142218, train_l2_u:0.187650, train_ssp_e:0.071229, train_ssp_u:0.093879,test_l2_e:0.186969, test_l2_u:0.352152
# 2025-10-18 05:53:08,237 : epoch:133, time:33.484905, train_mse_e:0.012785, train_mse_u:0.021168, train_l2_e:0.139543, train_l2_u:0.193791, train_ssp_e:0.069747, train_ssp_u:0.096453,test_l2_e:0.185645, test_l2_u:0.442026
# 2025-10-18 05:53:41,363 : epoch:134, time:33.120019, train_mse_e:0.012683, train_mse_u:0.021666, train_l2_e:0.138877, train_l2_u:0.197216, train_ssp_e:0.069449, train_ssp_u:0.098487,test_l2_e:0.185712, test_l2_u:0.339685
# 2025-10-18 05:53:42,029 : best model saved
# 2025-10-18 05:54:15,107 : epoch:135, time:33.075026, train_mse_e:0.012403, train_mse_u:0.019892, train_l2_e:0.137525, train_l2_u:0.184703, train_ssp_e:0.068824, train_ssp_u:0.092418,test_l2_e:0.184990, test_l2_u:0.351961
# 2025-10-18 05:54:48,118 : epoch:136, time:33.005528, train_mse_e:0.012299, train_mse_u:0.019805, train_l2_e:0.136336, train_l2_u:0.184260, train_ssp_e:0.068246, train_ssp_u:0.092190,test_l2_e:0.184326, test_l2_u:0.349402
# 2025-10-18 05:55:21,042 : epoch:137, time:32.920555, train_mse_e:0.012505, train_mse_u:0.020300, train_l2_e:0.139027, train_l2_u:0.186218, train_ssp_e:0.069595, train_ssp_u:0.093269,test_l2_e:0.185081, test_l2_u:0.336363
# 2025-10-18 05:55:21,700 : best model saved
# 2025-10-18 05:55:54,669 : epoch:138, time:32.965725, train_mse_e:0.012457, train_mse_u:0.020082, train_l2_e:0.138085, train_l2_u:0.184498, train_ssp_e:0.069162, train_ssp_u:0.092219,test_l2_e:0.185890, test_l2_u:0.343958
# 2025-10-18 05:56:27,611 : epoch:139, time:32.937870, train_mse_e:0.012350, train_mse_u:0.019557, train_l2_e:0.137125, train_l2_u:0.182016, train_ssp_e:0.068651, train_ssp_u:0.090932,test_l2_e:0.182887, test_l2_u:0.338943
# 2025-10-18 05:57:00,564 : epoch:140, time:32.947646, train_mse_e:0.012828, train_mse_u:0.021071, train_l2_e:0.139274, train_l2_u:0.192448, train_ssp_e:0.069773, train_ssp_u:0.096337,test_l2_e:0.183225, test_l2_u:0.343289
# 2025-10-18 05:57:33,491 : epoch:141, time:32.924778, train_mse_e:0.012443, train_mse_u:0.019943, train_l2_e:0.137804, train_l2_u:0.185066, train_ssp_e:0.068988, train_ssp_u:0.092530,test_l2_e:0.183752, test_l2_u:0.342982
# 2025-10-18 05:58:06,582 : epoch:142, time:33.086396, train_mse_e:0.012177, train_mse_u:0.018963, train_l2_e:0.136356, train_l2_u:0.180589, train_ssp_e:0.068267, train_ssp_u:0.090259,test_l2_e:0.185868, test_l2_u:0.339706
# 2025-10-18 05:58:39,873 : epoch:143, time:33.287181, train_mse_e:0.012194, train_mse_u:0.019026, train_l2_e:0.138529, train_l2_u:0.183817, train_ssp_e:0.069346, train_ssp_u:0.091848,test_l2_e:0.187101, test_l2_u:0.355398
# 2025-10-18 05:59:13,072 : epoch:144, time:33.193635, train_mse_e:0.012420, train_mse_u:0.019604, train_l2_e:0.140750, train_l2_u:0.191034, train_ssp_e:0.070188, train_ssp_u:0.095334,test_l2_e:0.189739, test_l2_u:0.344212
# 2025-10-18 05:59:46,425 : epoch:145, time:33.349177, train_mse_e:0.012178, train_mse_u:0.019016, train_l2_e:0.136213, train_l2_u:0.180713, train_ssp_e:0.068227, train_ssp_u:0.090335,test_l2_e:0.187668, test_l2_u:0.344201
# 2025-10-18 06:00:19,612 : epoch:146, time:33.179737, train_mse_e:0.012425, train_mse_u:0.019885, train_l2_e:0.138209, train_l2_u:0.190956, train_ssp_e:0.069186, train_ssp_u:0.095524,test_l2_e:0.182092, test_l2_u:0.339147
# 2025-10-18 06:00:53,004 : epoch:147, time:33.387931, train_mse_e:0.012418, train_mse_u:0.019086, train_l2_e:0.142733, train_l2_u:0.181976, train_ssp_e:0.071290, train_ssp_u:0.090933,test_l2_e:0.188130, test_l2_u:0.342265
# 2025-10-18 06:01:26,204 : epoch:148, time:33.193637, train_mse_e:0.011917, train_mse_u:0.018043, train_l2_e:0.135400, train_l2_u:0.177197, train_ssp_e:0.067701, train_ssp_u:0.088137,test_l2_e:0.212347, test_l2_u:0.354506
# 2025-10-18 06:01:59,533 : epoch:149, time:33.325008, train_mse_e:0.012073, train_mse_u:0.018326, train_l2_e:0.139411, train_l2_u:0.181171, train_ssp_e:0.069695, train_ssp_u:0.090491,test_l2_e:0.188184, test_l2_u:0.337206
# 2025-10-18 06:02:32,699 : epoch:150, time:33.158357, train_mse_e:0.012178, train_mse_u:0.018751, train_l2_e:0.138460, train_l2_u:0.180710, train_ssp_e:0.069173, train_ssp_u:0.090434,test_l2_e:0.196743, test_l2_u:0.340478
# 2025-10-18 06:03:05,708 : epoch:151, time:33.003175, train_mse_e:0.011995, train_mse_u:0.017868, train_l2_e:0.136141, train_l2_u:0.175718, train_ssp_e:0.068149, train_ssp_u:0.087744,test_l2_e:0.183248, test_l2_u:0.346037
# 2025-10-18 06:03:38,648 : epoch:152, time:32.934589, train_mse_e:0.011601, train_mse_u:0.017359, train_l2_e:0.133091, train_l2_u:0.172758, train_ssp_e:0.066597, train_ssp_u:0.086187,test_l2_e:0.181915, test_l2_u:0.340067
# 2025-10-18 06:04:11,624 : epoch:153, time:32.970878, train_mse_e:0.011712, train_mse_u:0.017959, train_l2_e:0.133447, train_l2_u:0.175635, train_ssp_e:0.066848, train_ssp_u:0.087711,test_l2_e:0.184252, test_l2_u:0.342777
# 2025-10-18 06:04:44,583 : epoch:154, time:32.953436, train_mse_e:0.011712, train_mse_u:0.017787, train_l2_e:0.134328, train_l2_u:0.175250, train_ssp_e:0.067219, train_ssp_u:0.087458,test_l2_e:0.189042, test_l2_u:0.337240
# 2025-10-18 06:05:17,538 : epoch:155, time:32.948860, train_mse_e:0.011963, train_mse_u:0.018046, train_l2_e:0.137461, train_l2_u:0.172948, train_ssp_e:0.068802, train_ssp_u:0.086449,test_l2_e:0.184896, test_l2_u:0.340238
# 2025-10-18 06:05:50,460 : epoch:156, time:32.914652, train_mse_e:0.012100, train_mse_u:0.018667, train_l2_e:0.135369, train_l2_u:0.177908, train_ssp_e:0.067815, train_ssp_u:0.089020,test_l2_e:0.183918, test_l2_u:0.334757
# 2025-10-18 06:05:51,250 : best model saved
# 2025-10-18 06:06:24,254 : epoch:157, time:33.000619, train_mse_e:0.011609, train_mse_u:0.017239, train_l2_e:0.132504, train_l2_u:0.169999, train_ssp_e:0.066336, train_ssp_u:0.084777,test_l2_e:0.182112, test_l2_u:0.342155
# 2025-10-18 06:06:57,216 : epoch:158, time:32.956710, train_mse_e:0.011467, train_mse_u:0.016837, train_l2_e:0.136696, train_l2_u:0.172423, train_ssp_e:0.068254, train_ssp_u:0.085717,test_l2_e:0.184160, test_l2_u:0.355422
# 2025-10-18 06:07:30,165 : epoch:159, time:32.944217, train_mse_e:0.011577, train_mse_u:0.017456, train_l2_e:0.134966, train_l2_u:0.173900, train_ssp_e:0.067541, train_ssp_u:0.086731,test_l2_e:0.184705, test_l2_u:0.336001
# 2025-10-18 06:08:03,180 : epoch:160, time:33.010523, train_mse_e:0.011795, train_mse_u:0.017428, train_l2_e:0.137360, train_l2_u:0.169890, train_ssp_e:0.068671, train_ssp_u:0.084895,test_l2_e:0.186696, test_l2_u:0.341200
# 2025-10-18 06:08:36,369 : epoch:161, time:33.183482, train_mse_e:0.011329, train_mse_u:0.016698, train_l2_e:0.130933, train_l2_u:0.170220, train_ssp_e:0.065517, train_ssp_u:0.084786,test_l2_e:0.185329, test_l2_u:0.343724
# 2025-10-18 06:09:09,497 : epoch:162, time:33.122505, train_mse_e:0.011455, train_mse_u:0.016698, train_l2_e:0.135044, train_l2_u:0.169883, train_ssp_e:0.067283, train_ssp_u:0.084568,test_l2_e:0.184683, test_l2_u:0.335475
# 2025-10-18 06:09:42,424 : epoch:163, time:32.923210, train_mse_e:0.011734, train_mse_u:0.016923, train_l2_e:0.139057, train_l2_u:0.173426, train_ssp_e:0.068944, train_ssp_u:0.086523,test_l2_e:0.183825, test_l2_u:0.338290
# 2025-10-18 06:10:15,482 : epoch:164, time:33.054468, train_mse_e:0.011545, train_mse_u:0.017037, train_l2_e:0.136636, train_l2_u:0.173272, train_ssp_e:0.068257, train_ssp_u:0.086452,test_l2_e:0.182916, test_l2_u:0.332987
# 2025-10-18 06:10:16,149 : best model saved
# 2025-10-18 06:10:49,054 : epoch:165, time:32.901895, train_mse_e:0.011094, train_mse_u:0.015823, train_l2_e:0.129764, train_l2_u:0.161090, train_ssp_e:0.064926, train_ssp_u:0.080360,test_l2_e:0.181638, test_l2_u:0.333771
# 2025-10-18 06:11:21,898 : epoch:166, time:32.839852, train_mse_e:0.011076, train_mse_u:0.015922, train_l2_e:0.129003, train_l2_u:0.161885, train_ssp_e:0.064595, train_ssp_u:0.080830,test_l2_e:0.180731, test_l2_u:0.332607
# 2025-10-18 06:11:22,550 : best model saved
# 2025-10-18 06:11:55,483 : epoch:167, time:32.930290, train_mse_e:0.010878, train_mse_u:0.015555, train_l2_e:0.127339, train_l2_u:0.159292, train_ssp_e:0.063778, train_ssp_u:0.079397,test_l2_e:0.180804, test_l2_u:0.336341
# 2025-10-18 06:12:28,234 : epoch:168, time:32.746504, train_mse_e:0.010987, train_mse_u:0.016083, train_l2_e:0.127982, train_l2_u:0.165171, train_ssp_e:0.064075, train_ssp_u:0.082227,test_l2_e:0.182007, test_l2_u:0.347562
# 2025-10-18 06:19:40,605 : epoch:181, time:33.159224, train_mse_e:0.010995, train_mse_u:0.015744, train_l2_e:0.130035, train_l2_u:0.162430, train_ssp_e:0.065124, train_ssp_u:0.081243,test_l2_e:0.186499, test_l2_u:0.337914
# 2025-10-18 06:20:13,661 : epoch:182, time:33.051287, train_mse_e:0.010996, train_mse_u:0.015567, train_l2_e:0.131440, train_l2_u:0.164920, train_ssp_e:0.065570, train_ssp_u:0.082349,test_l2_e:0.187552, test_l2_u:0.341302
# 2025-10-18 06:20:46,673 : epoch:183, time:33.007459, train_mse_e:0.010904, train_mse_u:0.015493, train_l2_e:0.132182, train_l2_u:0.164232, train_ssp_e:0.065984, train_ssp_u:0.081828,test_l2_e:0.182327, test_l2_u:0.337612
# 2025-10-18 06:21:19,703 : epoch:184, time:33.025649, train_mse_e:0.010806, train_mse_u:0.015257, train_l2_e:0.130080, train_l2_u:0.163308, train_ssp_e:0.065001, train_ssp_u:0.081552,test_l2_e:0.186275, test_l2_u:0.339790
# 2025-10-18 06:21:52,618 : epoch:185, time:32.912158, train_mse_e:0.010726, train_mse_u:0.015237, train_l2_e:0.129755, train_l2_u:0.163033, train_ssp_e:0.064852, train_ssp_u:0.081301,test_l2_e:0.184071, test_l2_u:0.334638
# 2025-10-18 06:22:25,423 : epoch:186, time:32.800134, train_mse_e:0.010656, train_mse_u:0.014057, train_l2_e:0.132607, train_l2_u:0.153518, train_ssp_e:0.066304, train_ssp_u:0.076585,test_l2_e:0.181489, test_l2_u:0.333084
# 2025-10-18 06:22:58,223 : epoch:187, time:32.796926, train_mse_e:0.010352, train_mse_u:0.013594, train_l2_e:0.127753, train_l2_u:0.152275, train_ssp_e:0.063869, train_ssp_u:0.075860,test_l2_e:0.182999, test_l2_u:0.336087
# 2025-10-18 06:23:30,863 : epoch:188, time:32.635296, train_mse_e:0.010353, train_mse_u:0.013848, train_l2_e:0.126880, train_l2_u:0.150830, train_ssp_e:0.063478, train_ssp_u:0.075186,test_l2_e:0.181362, test_l2_u:0.337433
# 2025-10-18 06:24:03,649 : epoch:189, time:32.782421, train_mse_e:0.010291, train_mse_u:0.013907, train_l2_e:0.124986, train_l2_u:0.152325, train_ssp_e:0.062554, train_ssp_u:0.075918,test_l2_e:0.182988, test_l2_u:0.336164
# 2025-10-18 06:24:36,275 : epoch:190, time:32.619093, train_mse_e:0.010281, train_mse_u:0.014035, train_l2_e:0.125993, train_l2_u:0.152483, train_ssp_e:0.063005, train_ssp_u:0.075956,test_l2_e:0.181793, test_l2_u:0.338038
# 2025-10-18 06:25:09,255 : epoch:191, time:32.976601, train_mse_e:0.010307, train_mse_u:0.014081, train_l2_e:0.126318, train_l2_u:0.154903, train_ssp_e:0.063140, train_ssp_u:0.077215,test_l2_e:0.182938, test_l2_u:0.338472
# 2025-10-18 06:25:42,392 : epoch:192, time:33.132605, train_mse_e:0.010093, train_mse_u:0.013424, train_l2_e:0.123369, train_l2_u:0.150004, train_ssp_e:0.061754, train_ssp_u:0.074687,test_l2_e:0.184885, test_l2_u:0.335928
# 2025-10-18 06:26:15,540 : epoch:193, time:33.142094, train_mse_e:0.010003, train_mse_u:0.013403, train_l2_e:0.123405, train_l2_u:0.152063, train_ssp_e:0.061691, train_ssp_u:0.075407,test_l2_e:0.184993, test_l2_u:0.334747
# 2025-10-18 06:26:48,611 : epoch:194, time:33.066743, train_mse_e:0.009980, train_mse_u:0.013606, train_l2_e:0.123392, train_l2_u:0.153698, train_ssp_e:0.061700, train_ssp_u:0.076184,test_l2_e:0.180547, test_l2_u:0.337534
# 2025-10-18 06:27:21,525 : epoch:195, time:32.909422, train_mse_e:0.010254, train_mse_u:0.014288, train_l2_e:0.125554, train_l2_u:0.157534, train_ssp_e:0.062758, train_ssp_u:0.078625,test_l2_e:0.192985, test_l2_u:0.351932
# 2025-10-18 06:27:54,443 : epoch:196, time:32.913047, train_mse_e:0.010601, train_mse_u:0.014629, train_l2_e:0.132565, train_l2_u:0.161412, train_ssp_e:0.065920, train_ssp_u:0.080429,test_l2_e:0.186265, test_l2_u:0.348862
# 2025-10-18 06:28:27,408 : epoch:197, time:32.961812, train_mse_e:0.010204, train_mse_u:0.013737, train_l2_e:0.125947, train_l2_u:0.151238, train_ssp_e:0.063019, train_ssp_u:0.075410,test_l2_e:0.187522, test_l2_u:0.331179
# 2025-10-18 06:28:28,202 : best model saved
# 2025-10-18 06:29:00,793 : epoch:198, time:32.587947, train_mse_e:0.009982, train_mse_u:0.013089, train_l2_e:0.123933, train_l2_u:0.146287, train_ssp_e:0.062014, train_ssp_u:0.072875,test_l2_e:0.184017, test_l2_u:0.334569
# 2025-10-18 06:29:33,617 : epoch:199, time:32.819299, train_mse_e:0.010492, train_mse_u:0.014767, train_l2_e:0.128067, train_l2_u:0.159232, train_ssp_e:0.064074, train_ssp_u:0.079589,test_l2_e:0.189136, test_l2_u:0.345116
# 2025-10-18 06:30:06,655 : epoch:200, time:33.033608, train_mse_e:0.011063, train_mse_u:0.016155, train_l2_e:0.130343, train_l2_u:0.166593, train_ssp_e:0.065260, train_ssp_u:0.083301,test_l2_e:0.184250, test_l2_u:0.339115
# 2025-10-18 06:30:39,673 : epoch:201, time:33.013600, train_mse_e:0.010108, train_mse_u:0.013660, train_l2_e:0.125762, train_l2_u:0.151328, train_ssp_e:0.062940, train_ssp_u:0.075573,test_l2_e:0.181202, test_l2_u:0.332598
# 2025-10-18 06:31:12,650 : epoch:202, time:32.971964, train_mse_e:0.010022, train_mse_u:0.013177, train_l2_e:0.125917, train_l2_u:0.148726, train_ssp_e:0.062959, train_ssp_u:0.074165,test_l2_e:0.180153, test_l2_u:0.337288
# 2025-10-18 06:31:45,658 : epoch:203, time:33.004162, train_mse_e:0.010278, train_mse_u:0.013577, train_l2_e:0.131350, train_l2_u:0.155157, train_ssp_e:0.065451, train_ssp_u:0.077348,test_l2_e:0.182937, test_l2_u:0.336957
# 2025-10-18 06:32:18,548 : epoch:204, time:32.886306, train_mse_e:0.009977, train_mse_u:0.013210, train_l2_e:0.123770, train_l2_u:0.146743, train_ssp_e:0.061926, train_ssp_u:0.073067,test_l2_e:0.180918, test_l2_u:0.333223
# 2025-10-18 06:32:51,416 : epoch:205, time:32.863615, train_mse_e:0.009875, train_mse_u:0.012981, train_l2_e:0.122801, train_l2_u:0.146204, train_ssp_e:0.061428, train_ssp_u:0.072883,test_l2_e:0.182466, test_l2_u:0.337431
# 2025-10-18 06:33:24,342 : epoch:206, time:32.921614, train_mse_e:0.009762, train_mse_u:0.012998, train_l2_e:0.122568, train_l2_u:0.149664, train_ssp_e:0.061337, train_ssp_u:0.074527,test_l2_e:0.182326, test_l2_u:0.343231
# 2025-10-18 06:33:56,928 : epoch:207, time:32.583310, train_mse_e:0.009637, train_mse_u:0.012862, train_l2_e:0.121158, train_l2_u:0.147387, train_ssp_e:0.060583, train_ssp_u:0.073322,test_l2_e:0.180280, test_l2_u:0.337298
# 2025-10-18 06:34:29,550 : epoch:208, time:32.616671, train_mse_e:0.009537, train_mse_u:0.012415, train_l2_e:0.119898, train_l2_u:0.143070, train_ssp_e:0.059999, train_ssp_u:0.071222,test_l2_e:0.180434, test_l2_u:0.332614
# ...
# 2025-10-18 08:35:20,839 : epoch:428, time:33.047041, train_mse_e:0.005490, train_mse_u:0.004146, train_l2_e:0.090713, train_l2_u:0.079164, train_ssp_e:0.045331, train_ssp_u:0.039440,test_l2_e:0.186268, test_l2_u:0.346126
# 2025-10-18 08:35:53,746 : epoch:429, time:32.901900, train_mse_e:0.005491, train_mse_u:0.004148, train_l2_e:0.090627, train_l2_u:0.079248, train_ssp_e:0.045292, train_ssp_u:0.039475,test_l2_e:0.186460, test_l2_u:0.346286
# 2025-10-18 08:36:26,754 : epoch:430, time:33.005011, train_mse_e:0.005481, train_mse_u:0.004132, train_l2_e:0.090627, train_l2_u:0.079083, train_ssp_e:0.045292, train_ssp_u:0.039387,test_l2_e:0.186759, test_l2_u:0.347564
# 2025-10-18 08:36:59,676 : epoch:431, time:32.917860, train_mse_e:0.005486, train_mse_u:0.004139, train_l2_e:0.090869, train_l2_u:0.079289, train_ssp_e:0.045414, train_ssp_u:0.039485,test_l2_e:0.186442, test_l2_u:0.347037
# 2025-10-18 08:37:32,533 : epoch:432, time:32.854481, train_mse_e:0.005481, train_mse_u:0.004129, train_l2_e:0.090673, train_l2_u:0.079058, train_ssp_e:0.045310, train_ssp_u:0.039392,test_l2_e:0.186647, test_l2_u:0.346626
# 2025-10-18 08:38:05,480 : epoch:433, time:32.942603, train_mse_e:0.005467, train_mse_u:0.004106, train_l2_e:0.090503, train_l2_u:0.078763, train_ssp_e:0.045230, train_ssp_u:0.039234,test_l2_e:0.186635, test_l2_u:0.347163
# 2025-10-18 08:38:38,289 : epoch:434, time:32.805456, train_mse_e:0.005465, train_mse_u:0.004106, train_l2_e:0.090402, train_l2_u:0.078939, train_ssp_e:0.045178, train_ssp_u:0.039321,test_l2_e:0.186808, test_l2_u:0.346971
# 2025-10-18 08:39:11,316 : epoch:435, time:33.024511, train_mse_e:0.005457, train_mse_u:0.004097, train_l2_e:0.090262, train_l2_u:0.078835, train_ssp_e:0.045110, train_ssp_u:0.039261,test_l2_e:0.186553, test_l2_u:0.347746
# 2025-10-18 08:39:44,110 : epoch:436, time:32.789127, train_mse_e:0.005459, train_mse_u:0.004102, train_l2_e:0.090376, train_l2_u:0.079162, train_ssp_e:0.045162, train_ssp_u:0.039404,test_l2_e:0.186643, test_l2_u:0.348030
# 2025-10-18 08:40:17,121 : epoch:437, time:33.008484, train_mse_e:0.005456, train_mse_u:0.004092, train_l2_e:0.090278, train_l2_u:0.078655, train_ssp_e:0.045112, train_ssp_u:0.039179,test_l2_e:0.186727, test_l2_u:0.347333
# 2025-10-18 08:40:49,973 : epoch:438, time:32.847104, train_mse_e:0.005445, train_mse_u:0.004074, train_l2_e:0.090204, train_l2_u:0.078441, train_ssp_e:0.045081, train_ssp_u:0.039078,test_l2_e:0.186820, test_l2_u:0.347390
# 2025-10-18 08:41:22,955 : epoch:439, time:32.979186, train_mse_e:0.005444, train_mse_u:0.004066, train_l2_e:0.090265, train_l2_u:0.078231, train_ssp_e:0.045110, train_ssp_u:0.038981,test_l2_e:0.186703, test_l2_u:0.347459
# 2025-10-18 08:41:55,925 : epoch:440, time:32.965741, train_mse_e:0.005437, train_mse_u:0.004055, train_l2_e:0.090165, train_l2_u:0.078057, train_ssp_e:0.045061, train_ssp_u:0.038893,test_l2_e:0.186523, test_l2_u:0.347190
# 2025-10-18 08:42:28,972 : epoch:441, time:33.043901, train_mse_e:0.005437, train_mse_u:0.004060, train_l2_e:0.090115, train_l2_u:0.078193, train_ssp_e:0.045038, train_ssp_u:0.038957,test_l2_e:0.186786, test_l2_u:0.347762
# 2025-10-18 08:43:02,003 : epoch:442, time:33.026881, train_mse_e:0.005429, train_mse_u:0.004043, train_l2_e:0.090017, train_l2_u:0.077927, train_ssp_e:0.044988, train_ssp_u:0.038831,test_l2_e:0.186781, test_l2_u:0.347871
# 2025-10-18 08:43:35,021 : epoch:443, time:33.013571, train_mse_e:0.005429, train_mse_u:0.004044, train_l2_e:0.090042, train_l2_u:0.077987, train_ssp_e:0.045001, train_ssp_u:0.038855,test_l2_e:0.186741, test_l2_u:0.347483
# 2025-10-18 08:44:08,125 : epoch:444, time:33.100737, train_mse_e:0.005421, train_mse_u:0.004030, train_l2_e:0.090010, train_l2_u:0.077852, train_ssp_e:0.044982, train_ssp_u:0.038793,test_l2_e:0.186846, test_l2_u:0.347729
# 2025-10-18 08:44:41,087 : epoch:445, time:32.957901, train_mse_e:0.005424, train_mse_u:0.004035, train_l2_e:0.090004, train_l2_u:0.077868, train_ssp_e:0.044983, train_ssp_u:0.038797,test_l2_e:0.186739, test_l2_u:0.347685
# 2025-10-18 08:45:13,946 : epoch:446, time:32.854078, train_mse_e:0.005416, train_mse_u:0.004023, train_l2_e:0.089900, train_l2_u:0.077649, train_ssp_e:0.044928, train_ssp_u:0.038693,test_l2_e:0.186838, test_l2_u:0.348072
# 2025-10-18 08:51:54,166 : epoch:458, time:33.323052, train_mse_e:0.005379, train_mse_u:0.003968, train_l2_e:0.089553, train_l2_u:0.077051, train_ssp_e:0.044755, train_ssp_u:0.038396,test_l2_e:0.186975, test_l2_u:0.348766
# 2025-10-18 08:52:27,429 : epoch:459, time:33.256733, train_mse_e:0.005382, train_mse_u:0.003974, train_l2_e:0.089633, train_l2_u:0.077198, train_ssp_e:0.044798, train_ssp_u:0.038474,test_l2_e:0.186974, test_l2_u:0.348931
# 2025-10-18 08:53:00,547 : epoch:460, time:33.113386, train_mse_e:0.005379, train_mse_u:0.003972, train_l2_e:0.089623, train_l2_u:0.077187, train_ssp_e:0.044790, train_ssp_u:0.038459,test_l2_e:0.186918, test_l2_u:0.348840
# 2025-10-18 08:53:33,693 : epoch:461, time:33.141370, train_mse_e:0.005373, train_mse_u:0.003955, train_l2_e:0.089508, train_l2_u:0.076860, train_ssp_e:0.044733, train_ssp_u:0.038305,test_l2_e:0.187098, test_l2_u:0.349040
# 2025-10-18 08:54:06,822 : epoch:462, time:33.126273, train_mse_e:0.005372, train_mse_u:0.003958, train_l2_e:0.089520, train_l2_u:0.076970, train_ssp_e:0.044740, train_ssp_u:0.038352,test_l2_e:0.187036, test_l2_u:0.349028
# 2025-10-18 08:54:39,875 : epoch:463, time:33.049066, train_mse_e:0.005369, train_mse_u:0.003954, train_l2_e:0.089489, train_l2_u:0.076950, train_ssp_e:0.044724, train_ssp_u:0.038344,test_l2_e:0.186877, test_l2_u:0.348857
# 2025-10-18 08:55:12,860 : epoch:464, time:32.980178, train_mse_e:0.005370, train_mse_u:0.003956, train_l2_e:0.089507, train_l2_u:0.077017, train_ssp_e:0.044731, train_ssp_u:0.038379,test_l2_e:0.186976, test_l2_u:0.349014
# 2025-10-18 08:55:45,963 : epoch:465, time:33.100191, train_mse_e:0.005365, train_mse_u:0.003946, train_l2_e:0.089456, train_l2_u:0.076812, train_ssp_e:0.044707, train_ssp_u:0.038282,test_l2_e:0.187063, test_l2_u:0.349047
# 2025-10-18 08:56:18,821 : epoch:466, time:32.853362, train_mse_e:0.005366, train_mse_u:0.003949, train_l2_e:0.089446, train_l2_u:0.076787, train_ssp_e:0.044700, train_ssp_u:0.038266,test_l2_e:0.187059, test_l2_u:0.349004
# 2025-10-18 08:56:51,898 : epoch:467, time:33.074220, train_mse_e:0.005363, train_mse_u:0.003943, train_l2_e:0.089418, train_l2_u:0.076730, train_ssp_e:0.044689, train_ssp_u:0.038239,test_l2_e:0.186983, test_l2_u:0.348994
# 2025-10-18 08:57:25,051 : epoch:468, time:33.148301, train_mse_e:0.005363, train_mse_u:0.003944, train_l2_e:0.089439, train_l2_u:0.076781, train_ssp_e:0.044700, train_ssp_u:0.038265,test_l2_e:0.187011, test_l2_u:0.349111
# 2025-10-18 08:57:58,052 : epoch:469, time:32.997220, train_mse_e:0.005358, train_mse_u:0.003935, train_l2_e:0.089378, train_l2_u:0.076648, train_ssp_e:0.044669, train_ssp_u:0.038199,test_l2_e:0.186998, test_l2_u:0.349332
# 2025-10-18 08:58:31,010 : epoch:470, time:32.953266, train_mse_e:0.005357, train_mse_u:0.003935, train_l2_e:0.089364, train_l2_u:0.076665, train_ssp_e:0.044661, train_ssp_u:0.038207,test_l2_e:0.187074, test_l2_u:0.349369
# 2025-10-18 08:59:03,949 : epoch:471, time:32.934727, train_mse_e:0.005357, train_mse_u:0.003934, train_l2_e:0.089380, train_l2_u:0.076687, train_ssp_e:0.044669, train_ssp_u:0.038219,test_l2_e:0.187033, test_l2_u:0.349181
# 2025-10-18 08:59:37,036 : epoch:472, time:33.084452, train_mse_e:0.005362, train_mse_u:0.003945, train_l2_e:0.089436, train_l2_u:0.076769, train_ssp_e:0.044699, train_ssp_u:0.038258,test_l2_e:0.187075, test_l2_u:0.349376
# 2025-10-18 09:00:09,995 : epoch:473, time:32.954476, train_mse_e:0.005355, train_mse_u:0.003929, train_l2_e:0.089378, train_l2_u:0.076575, train_ssp_e:0.044670, train_ssp_u:0.038164,test_l2_e:0.187070, test_l2_u:0.349371
# 2025-10-18 09:00:42,947 : epoch:474, time:32.947723, train_mse_e:0.005351, train_mse_u:0.003923, train_l2_e:0.089338, train_l2_u:0.076506, train_ssp_e:0.044648, train_ssp_u:0.038131,test_l2_e:0.187047, test_l2_u:0.349320
# 2025-10-18 09:01:15,859 : epoch:475, time:32.908424, train_mse_e:0.005355, train_mse_u:0.003932, train_l2_e:0.089358, train_l2_u:0.076600, train_ssp_e:0.044652, train_ssp_u:0.038174,test_l2_e:0.187088, test_l2_u:0.349392
# 2025-10-18 09:01:48,590 : epoch:476, time:32.726941, train_mse_e:0.005351, train_mse_u:0.003928, train_l2_e:0.089312, train_l2_u:0.076545, train_ssp_e:0.044643, train_ssp_u:0.038147,test_l2_e:0.187053, test_l2_u:0.349566
# 2025-10-18 09:02:21,483 : epoch:477, time:32.886490, train_mse_e:0.005349, train_mse_u:0.003923, train_l2_e:0.089298, train_l2_u:0.076481, train_ssp_e:0.044626, train_ssp_u:0.038117,test_l2_e:0.187070, test_l2_u:0.349382
# 2025-10-18 09:02:54,306 : epoch:478, time:32.817043, train_mse_e:0.005346, train_mse_u:0.003918, train_l2_e:0.089270, train_l2_u:0.076435, train_ssp_e:0.044616, train_ssp_u:0.038094,test_l2_e:0.187048, test_l2_u:0.349404
# 2025-10-18 09:03:27,118 : epoch:479, time:32.806364, train_mse_e:0.005346, train_mse_u:0.003919, train_l2_e:0.089282, train_l2_u:0.076481, train_ssp_e:0.044620, train_ssp_u:0.038117,test_l2_e:0.187070, test_l2_u:0.349443
# 2025-10-18 09:04:00,238 : epoch:480, time:33.116823, train_mse_e:0.005347, train_mse_u:0.003922, train_l2_e:0.089283, train_l2_u:0.076446, train_ssp_e:0.044622, train_ssp_u:0.038098,test_l2_e:0.187089, test_l2_u:0.349534
# 2025-10-18 09:04:33,091 : epoch:481, time:32.848006, train_mse_e:0.005346, train_mse_u:0.003919, train_l2_e:0.089247, train_l2_u:0.076417, train_ssp_e:0.044602, train_ssp_u:0.038084,test_l2_e:0.187055, test_l2_u:0.349464
# 2025-10-18 09:05:05,915 : epoch:482, time:32.818695, train_mse_e:0.005345, train_mse_u:0.003920, train_l2_e:0.089266, train_l2_u:0.076467, train_ssp_e:0.044614, train_ssp_u:0.038109,test_l2_e:0.187058, test_l2_u:0.349480
# 2025-10-18 09:05:38,717 : epoch:483, time:32.796237, train_mse_e:0.005345, train_mse_u:0.003918, train_l2_e:0.089233, train_l2_u:0.076399, train_ssp_e:0.044595, train_ssp_u:0.038079,test_l2_e:0.187074, test_l2_u:0.349471
# 2025-10-18 09:06:11,430 : epoch:484, time:32.708020, train_mse_e:0.005344, train_mse_u:0.003915, train_l2_e:0.089268, train_l2_u:0.076419, train_ssp_e:0.044614, train_ssp_u:0.038087,test_l2_e:0.187105, test_l2_u:0.349610
# 2025-10-18 09:06:44,179 : epoch:485, time:32.741997, train_mse_e:0.005347, train_mse_u:0.003921, train_l2_e:0.089273, train_l2_u:0.076458, train_ssp_e:0.044616, train_ssp_u:0.038104,test_l2_e:0.187072, test_l2_u:0.349560
# 2025-10-18 09:07:17,013 : epoch:486, time:32.828740, train_mse_e:0.005345, train_mse_u:0.003918, train_l2_e:0.089263, train_l2_u:0.076430, train_ssp_e:0.044608, train_ssp_u:0.038092,test_l2_e:0.187116, test_l2_u:0.349453
# 2025-10-18 09:07:49,828 : epoch:487, time:32.809684, train_mse_e:0.005345, train_mse_u:0.003919, train_l2_e:0.089248, train_l2_u:0.076398, train_ssp_e:0.044604, train_ssp_u:0.038075,test_l2_e:0.187120, test_l2_u:0.349599
# 2025-10-18 09:08:22,758 : epoch:488, time:32.926965, train_mse_e:0.005343, train_mse_u:0.003915, train_l2_e:0.089245, train_l2_u:0.076408, train_ssp_e:0.044603, train_ssp_u:0.038080,test_l2_e:0.187068, test_l2_u:0.349488
# 2025-10-18 09:08:55,631 : epoch:489, time:32.868548, train_mse_e:0.005340, train_mse_u:0.003911, train_l2_e:0.089202, train_l2_u:0.076334, train_ssp_e:0.044584, train_ssp_u:0.038045,test_l2_e:0.187085, test_l2_u:0.349569
# 2025-10-18 09:09:28,474 : epoch:490, time:32.836924, train_mse_e:0.005346, train_mse_u:0.003918, train_l2_e:0.089241, train_l2_u:0.076366, train_ssp_e:0.044597, train_ssp_u:0.038062,test_l2_e:0.187011, test_l2_u:0.349303
# 2025-10-18 09:10:01,593 : epoch:491, time:33.111403, train_mse_e:0.005337, train_mse_u:0.003905, train_l2_e:0.089182, train_l2_u:0.076226, train_ssp_e:0.044570, train_ssp_u:0.037989,test_l2_e:0.187082, test_l2_u:0.349476
# 2025-10-18 09:10:34,980 : epoch:492, time:33.380521, train_mse_e:0.005340, train_mse_u:0.003909, train_l2_e:0.089212, train_l2_u:0.076320, train_ssp_e:0.044586, train_ssp_u:0.038038,test_l2_e:0.187131, test_l2_u:0.349501
# 2025-10-18 09:11:08,124 : epoch:493, time:33.138270, train_mse_e:0.005340, train_mse_u:0.003913, train_l2_e:0.089213, train_l2_u:0.076324, train_ssp_e:0.044588, train_ssp_u:0.038039,test_l2_e:0.187046, test_l2_u:0.349513
# 2025-10-18 09:11:41,304 : epoch:494, time:33.175284, train_mse_e:0.005339, train_mse_u:0.003908, train_l2_e:0.089218, train_l2_u:0.076323, train_ssp_e:0.044587, train_ssp_u:0.038037,test_l2_e:0.187151, test_l2_u:0.349523
# 2025-10-18 09:12:14,015 : epoch:495, time:32.705353, train_mse_e:0.005340, train_mse_u:0.003911, train_l2_e:0.089202, train_l2_u:0.076317, train_ssp_e:0.044582, train_ssp_u:0.038037,test_l2_e:0.187042, test_l2_u:0.349499
# 2025-10-18 09:12:47,003 : epoch:496, time:32.982857, train_mse_e:0.005339, train_mse_u:0.003909, train_l2_e:0.089183, train_l2_u:0.076262, train_ssp_e:0.044568, train_ssp_u:0.038005,test_l2_e:0.187048, test_l2_u:0.349531
# 2025-10-18 09:13:19,873 : epoch:497, time:32.866010, train_mse_e:0.005340, train_mse_u:0.003911, train_l2_e:0.089203, train_l2_u:0.076314, train_ssp_e:0.044581, train_ssp_u:0.038034,test_l2_e:0.187096, test_l2_u:0.349680
# 2025-10-18 09:13:52,847 : epoch:498, time:32.968395, train_mse_e:0.005341, train_mse_u:0.003911, train_l2_e:0.089229, train_l2_u:0.076338, train_ssp_e:0.044595, train_ssp_u:0.038046,test_l2_e:0.187084, test_l2_u:0.349574
# 2025-10-18 09:14:25,860 : epoch:499, time:33.008602, train_mse_e:0.005338, train_mse_u:0.003906, train_l2_e:0.089175, train_l2_u:0.076262, train_ssp_e:0.044568, train_ssp_u:0.038009,test_l2_e:0.187113, test_l2_u:0.349559

# %%
pred = torch.zeros(test_u.shape)
prede = torch.zeros(test_e.shape)
index = 0
model = torch.load(path_model).cuda()
test_loader = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(test_a, test_u,test_e), batch_size=1, shuffle=False)
with torch.no_grad():
    for x, y,e in test_loader:
        test_l2 = 0
        x, y ,e = x.cuda(), y.cuda(), e.cuda()

        outeta,out = model(x)
        out = out.view(1, S, S, T)
        outeta = outeta.view(1,S,S,T)
#        out = y_normalizer.decode(out)
        pred[index] = out
        prede[index] = outeta

        test_l2 += myloss(out.view(1, -1), y.view(1, -1)).item()
        test_l2 += myloss(outeta.view(1,-1),e.view(1,-1)).item()
        #print(index, test_l2)
        logger.info('%d    %f' % (index,test_l2))
        index = index + 1

scipy.io.savemat(path+'/pred.mat', mdict={'pred': pred.cpu().numpy(), 'prede': prede.cpu().numpy(), 'test_u': test_u.cpu().numpy(), 'test_e': test_e.cpu().numpy()})
# Out:
# 2025-10-18 20:28:42,247 : 0    0.411797
# 2025-10-18 20:28:42,338 : 1    0.420941
# 2025-10-18 20:28:42,430 : 2    0.501765
# 2025-10-18 20:28:42,520 : 3    0.554314
# 2025-10-18 20:28:42,611 : 4    0.458553
# 2025-10-18 20:28:42,701 : 5    0.424976
# 2025-10-18 20:28:42,791 : 6    0.744665
# 2025-10-18 20:28:42,882 : 7    0.519301
# 2025-10-18 20:28:42,973 : 8    0.471453
# 2025-10-18 20:28:43,063 : 9    0.512453
# 2025-10-18 20:28:43,153 : 10    0.662857
    ftrue = np.fft.fft2(true,axes=ax)
    norm_error = np.linalg.norm(fpred-ftrue,axis=ax)
    norm_pred = np.linalg.norm(fpred,axis=ax)
    norm_true = np.linalg.norm(ftrue,axis=ax)
    ssps = norm_error/(norm_pred+norm_true)
    ssp = np.mean(ssps)
    return ssp,ssps

T_in = 16
T = 16
#prefix = 'exp/your target dir/'
path_image = prefix+'image'
if not os.path.exists(path_image):
    os.makedirs(path_image)
reader = MatReader(prefix+'pred.mat', to_torch=False)
true_e = reader.read_field('test_e')
true_u = reader.read_field('test_u')
pred_e = reader.read_field('prede')
pred_u = reader.read_field('pred')
# mean over axis 1,2,3 while keep axis 0, then normalized with hs
rmse_e_hs = np.mean(np.sqrt(np.mean((pred_e-true_e)**2,axis=(1,2,3)))/hs)
rmse_u_hs = np.mean(np.sqrt(np.mean((pred_u-true_u)**2,axis=(1,2,3)))/hs)
mae_e_hs = np.mean(np.mean(np.abs(pred_e-true_e),axis=(1,2,3))/hs)
mae_u_hs = np.mean(np.mean(np.abs(pred_u-true_u),axis=(1,2,3))/hs)
ssp_e,ssps_e = get_ssp(pred_e,true_e)
ssp_u,ssps_u = get_ssp(pred_u,true_u)
print('normalized by Hs->rmse_e:%f, rmse_u:%f, mae_e:%f, mae_u:%f, ssp_e:%f, ssp_u:%f' % (rmse_e_hs,rmse_u_hs,mae_e_hs,mae_u_hs,ssp_e,ssp_u)) 

mae_e_time = np.mean(np.mean(np.abs(pred_e-true_e),axis=(1,2))/hs.reshape(-1,1),axis=(0))
mae_u_time = np.mean(np.mean(np.abs(pred_u-true_u),axis=(1,2))/hs.reshape(-1,1),axis=(0))
mae_u_space = np.mean(np.mean(np.abs(pred_u-true_u),axis=(3))/hs.reshape(-1,1,1),axis=(0))
mae_e_space = np.mean(np.mean(np.abs(pred_e-true_e),axis=(3))/hs.reshape(-1,1,1),axis=(0))
mae_u_st = np.mean(np.abs(pred_u-true_u)/hs.reshape(-1,1,1,1),axis=(0))
mae_e_st = np.mean(np.abs(pred_e-true_e)/hs.reshape(-1,1,1,1),axis=(0))

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import cmocean

def plot_and_gif(tmp_eta, x, y, name,title,cmap,clim,label,save_fig=False,save_gif=False,grid=False,size=(8,6)):
    # Create figure and axes
    fig, ax = plt.subplots(figsize=size)
    levels = np.linspace(clim[0], clim[1], 100)  
    
    # Create a pcolormesh plot for the first frame
    if save_fig:
        #mesh = ax.pcolormesh(x, y, tmp_eta[:,:], cmap=cmap)
        mesh = ax.contourf(x, y, tmp_eta[:,:], cmap=cmap,levels=levels,extend='both') # levels=50
        mesh.set_edgecolor("face")
    else:      
        #mesh = ax.pcolormesh(x, y, tmp_eta[:,:,0], cmap=cmap)  # Use 'inferno' colormap for smooth visualization
        mesh = ax.contourf(x, y, tmp_eta[:,:,0], cmap=cmap,levels=levels,extend='both') # levels=50
    #mesh.set_clim(clim[0], clim[1])
    colorbar = plt.colorbar(mesh)
    colorbar.set_label(label, fontsize=16,fontstyle='italic')  # Colorbar label with LaTeX formatting
    ticks = np.linspace(clim[0], clim[1], 5)   
    colorbar.set_ticks(ticks)

    tick_labels = [f'{x:.2f}' for x in ticks]  
    colorbar.set_ticklabels(tick_labels)
       
    plt.title(title)
    ax.set_xlabel(r'$x$ (m)', fontsize=16, fontstyle='italic')
    ax.set_ylabel(r'$y$ (m)', fontsize=16, fontstyle='italic')
    plt.grid(grid)
    if save_fig:
        # Save figure as a jpg, high dpi, tight bounding box
        plt.savefig(name+'.jpg', dpi=600, bbox_inches='tight')
        plt.savefig(name+'.pdf', dpi=600, bbox_inches='tight')
        plt.savefig(name+'.eps', bbox_inches='tight')
    if not save_gif:
        return 
    plt.show()
    # Update function for animation
    def update(frame):
        ax.clear()
        #mesh = ax.pcolormesh(x, y, tmp_eta[:,:,frame], cmap=cmap)  # Use 'inferno' colormap for smooth visualization
        mesh = ax.contourf(x, y, tmp_eta[:,:,frame], cmap=cmap,levels=levels,extend='both') # levels=50
        ax.set_title(title+' '+f'Frame {frame+1}')
        ax.set_xlabel(r'$x$ (m)', fontsize=16, fontstyle='italic')
        ax.set_ylabel(r'$y$ (m)', fontsize=16, fontstyle='italic')
        plt.grid(grid)
        return mesh,

    # Create animation
    ani = animation.FuncAnimation(fig, update, frames=tmp_eta.shape[2], interval=400, blit=False)

    # Save animation as a GIF with LaTeX formatted axis labels and colorbar label
    ani.save(name+'.gif', writer='pillow', fps=5)  # Save as a GIF
    plt.show()
    return

# %%
def plot_space(tmp_eta, x, y, name,title,cmap,clim,label,save_fig=False,save_gif=False,grid=False,size=(6,4.5)):
    fig, ax = plt.subplots(figsize=size)

    # Create a pcolormesh plot for the first frame
    #mesh = ax.pcolormesh(x, y, tmp_eta[:,:], cmap=cmap)
    levels = np.linspace(clim[0], clim[1], 100)
    mesh = ax.contourf(x, y, tmp_eta, cmap=cmap,levels=levels,extend='both') #levels = 50
    mesh.set_edgecolor("face")
    mesh.set_clim(clim[0], clim[1])
    colorbar = plt.colorbar(mesh)
    colorbar.set_label(label, fontsize=16,fontstyle='italic')  # Colorbar label with LaTeX formatting
    plt.title(title)
    ax.set_xlabel(r'$x$ (m)', fontsize=16, fontstyle='italic')
    ax.set_ylabel(r'$y$ (m)', fontsize=16, fontstyle='italic')
    plt.grid(grid)
    if save_fig:
        # Save figure as a jpg, high dpi, tight bounding box
        plt.savefig(name+'.eps', bbox_inches='tight')
        plt.savefig(name+'.jpg', dpi=600, bbox_inches='tight')
        plt.savefig(name+'.pdf', dpi=600, bbox_inches='tight')
    if not save_gif:
        return 
    plt.show()
    return

# %%
def show_video_line(data, ncols, vmax=0.6, vmin=0.0, cmap='gray',startnum = 0,norm=None, cbar=False, format='png', out_path=None, use_rgb=False):
    """generate images with a video sequence"""
    fig, axes = plt.subplots(nrows=1, ncols=ncols, figsize=(3.25 * ncols, 3))
    plt.subplots_adjust(wspace=0.1, hspace=0)
    levels = np.linspace(vmin, vmax, 100)
    if len(data.shape) > 3:
        data = data.swapaxes(1,2).swapaxes(2,3)

    images = []
    if ncols == 1:
        im = axes.contourf(data[:,:,0], cmap=cmap, norm=norm,levels=levels)
        im.set_edgecolor("face")
        images.append(im)
        axes.axis('off')
        im.set_clim(vmin, vmax)
    else:
        for t, ax in enumerate(axes.flat):
            im = ax.contourf(data[:,:,t], cmap=cmap, norm=norm,levels=levels,extend='both')
            im.set_edgecolor("face")
            images.append(im)
            ax.axis('off')
            im.set_clim(vmin, vmax)
            ax.title.set_text(f'Frame {startnum+t+1}')
            ax.title.set_fontsize(25)

    if cbar and ncols > 1:
        cbaxes = fig.add_axes([0.91, 0.15, 0.04 / ncols, 0.7]) 
        cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.1, cax=cbaxes)

    ticks = np.linspace(vmin, vmax, 5)  
    cbar.set_ticks(ticks)
    #font size of cbar
    cbar.ax.tick_params(labelsize=20)  

    tick_labels = [f'{x:.2f}' for x in ticks]  
    cbar.set_ticklabels(tick_labels)

    plt.show()
    if out_path is not None:
        fig.savefig(out_path, format=format, pad_inches=0, bbox_inches='tight')
    plt.close()

# %%
T_in = 16
T = 16
#set if you want to check the results only, need to recover x_domain,y_domain,hs from the read data part.
#prefix = 'exp/your target dir/'  
path_image = prefix+'image'
if not os.path.exists(path_image):
    os.makedirs(path_image)
reader = MatReader(prefix+'pred.mat', to_torch=False)
true_e = reader.read_field('test_e')
true_u = reader.read_field('test_u')
pred_e = reader.read_field('prede')
pred_u = reader.read_field('pred')
# mean over axis 1,2,3 while keep axis 0, then normalized with hs
rmse_e_hs = np.mean(np.sqrt(np.mean((pred_e-true_e)**2,axis=(1,2,3)))/hs)
rmse_u_hs = np.mean(np.sqrt(np.mean((pred_u-true_u)**2,axis=(1,2,3)))/hs)
mae_e_hs = np.mean(np.mean(np.abs(pred_e-true_e),axis=(1,2,3))/hs)
mae_u_hs = np.mean(np.mean(np.abs(pred_u-true_u),axis=(1,2,3))/hs)
ssp_e,ssps_e = get_ssp(pred_e,true_e)
ssp_u,ssps_u = get_ssp(pred_u,true_u)
print('normalized by Hs->rmse_e:%f, rmse_u:%f, mae_e:%f, mae_u:%f, ssp_e:%f, ssp_u:%f' % (rmse_e_hs,rmse_u_hs,mae_e_hs,mae_u_hs,ssp_e,ssp_u)) 

mae_e_time = np.mean(np.mean(np.abs(pred_e-true_e),axis=(1,2))/hs.reshape(-1,1),axis=(0))
mae_u_time = np.mean(np.mean(np.abs(pred_u-true_u),axis=(1,2))/hs.reshape(-1,1),axis=(0))
mae_u_space = np.mean(np.mean(np.abs(pred_u-true_u),axis=(3))/hs.reshape(-1,1,1),axis=(0))
mae_e_space = np.mean(np.mean(np.abs(pred_e-true_e),axis=(3))/hs.reshape(-1,1,1),axis=(0))
mae_u_st = np.mean(np.abs(pred_u-true_u)/hs.reshape(-1,1,1,1),axis=(0))
mae_e_st = np.mean(np.abs(pred_e-true_e)/hs.reshape(-1,1,1,1),axis=(0))

# plot mae with time and space
plt.figure(figsize=(6,4.5))
plt.title('MAE for prediction and reconstruction',fontsize=14, fontstyle='normal')
plt.plot(t_domain[T_in:T_in+T],mae_u_time,label='predicted elevation',marker='o')
plt.plot(t_domain[:T_in],mae_e_time,label='reconstructed elevation',marker='*')
plt.legend(fontsize=10,loc='upper left')
plt.xlabel('time(s)',fontsize=16, fontstyle='italic')
plt.ylabel('$MAE/H_s$',fontsize=16, fontstyle='italic')
plt.xlim([0,32])
#plt.ylim([0.02,0.035])
# save eps ,tight layout, high dpi
#plt.savefig(path_image+'/mae_time.jpg',dpi=300,bbox_inches = 'tight')
#plt.savefig(path_image+'/mae_time.pdf',dpi=600,bbox_inches = 'tight')
plt.show()

#plt.figure()
# plot mae in 2d meshgrid (x_domain,y_domain)
sub =2
x = x_domain[::sub]
y = y_domain[::sub]
plot_and_gif(mae_u_space,x,y,path_image+'/mae_u_space','MAE for prediction',cmap=cmocean.cm.balance,clim=[0,0.2],label=r'$MAE/H_s$',save_fig=True,save_gif=False,grid=False)
plot_and_gif(mae_e_space,x,y,path_image+'/mae_e_space','MAE for reconstrution',cmap=cmocean.cm.balance,clim=[0,0.08],label=r'$MAE/H_s$',save_fig=True,save_gif=False,grid=False)
#plot mae in 2d meshgrid with time 
show_video_line(mae_u_st[:,:,:8],ncols=int(mae_u_st.shape[2]/2),vmax=0.2,vmin=0.0,cmap=cmocean.cm.balance,startnum=0,cbar=True,format='pdf',out_path=path_image+'/mae_u_st1.pdf',use_rgb=False)
show_video_line(mae_u_st[:,:,8:],ncols=int(mae_u_st.shape[2]/2),vmax=0.2,vmin=0.0,cmap=cmocean.cm.balance,startnum=8,cbar=True,format='pdf',out_path=path_image+'/mae_u_st2.pdf',use_rgb=False)
show_video_line(mae_e_st[:,:,:8],ncols=int(mae_e_st.shape[2]/2),vmax=0.1,vmin=0.0,cmap=cmocean.cm.balance,startnum=0,cbar=True,format='pdf',out_path=path_image+'/mae_e_st1.pdf',use_rgb=False)
show_video_line(mae_e_st[:,:,8:],ncols=int(mae_e_st.shape[2]/2),vmax=0.1,vmin=0.0,cmap=cmocean.cm.balance,startnum=8,cbar=True,format='pdf',out_path=path_image+'/mae_e_st2.pdf',use_rgb=False)

plot_and_gif(mae_e_st,x,y,path_image+'/mae_r_st','MAE for reconstruction',cmap=cmocean.cm.balance,clim=[0,0.1],label=r'$MAE/H_s$',save_fig=False,save_gif=True,grid=False)
plot_and_gif(mae_u_st,x,y,path_image+'/mae_u_st','MAE for prediction',cmap=cmocean.cm.balance,clim=[0,0.2],label=r'$MAE/H_s$',save_fig=False,save_gif=True,grid=False)
# Out:
# normalized by Hs->rmse_e:0.045343, rmse_u:0.082862, mae_e:0.034548, mae_u:0.052706, ssp_e:0.092759, ssp_u:0.169024
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 40
#      37 mae_e_st = np.mean(np.abs(pred_e-true_e)/hs.reshape(-1,1,1,1),axis=(0))
#      39 # plot mae with time and space
# ---> 40 plt.figure(figsize=(6,4.5))
#      41 plt.title('MAE for prediction and reconstruction',fontsize=14, fontstyle='normal')
#      42 plt.plot(t_domain[T_in:T_in+T],mae_u_time,label='predicted elevation',marker='o')
#
# NameError: name 'plt' is not defined
